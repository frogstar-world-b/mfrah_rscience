# %% [markdown]
# ## Modeling
#
# I decided to be bold and use a pretrained BERT model. Then I used a text feature based on combining the title and body, and a set of engineered features. From BERT I used the tokanization and embeddings. Then I built my own regression model for the head.
#
# I choose to use a few layers deep NN. Depth should help with the non-linearities and multi-modalities. The presence of the (scaled) numerical feature is mean to help bring down the bias. I used the Huber loss (SmoothL1Loss) for robust regression.
#
# Given I am working on an older M1 Macbook air, computations were slow. So I did not get to do much hyper-parameter tuning.
#
# Another idea that could have helped with faster computations (but I thought about it late) is to actually download the BERT embeddings for our dataset then treat them like features, combine them with the numerical features and use them together in a regression model to predict the score.

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm

import torch
import torch.nn as nn
from transformers import BertTokenizer, BertModel
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import StepLR

from sklearn.model_selection import train_test_split
from sklearn.metrics import (mean_absolute_error, 
                             mean_squared_error, 
                             mean_absolute_percentage_error,
                             r2_score)

from utils4 import *

# %%
# load the data
df = load_data('data_features.csv')
# Split into train/val/test sets (70/15/15)
df_train, df_val, df_test = prepare_data(df, test_size=.15)

# %%
# tokenize the data
train_encodings, train_labels, train_numerical_features = tokenize_data(
    df_train, df_train[NUMERICAL_FEATURES].values)
val_encodings, val_labels, val_numerical_features = tokenize_data(
    df_val, df_val[NUMERICAL_FEATURES].values)
test_encodings, test_labels, test_numerical_features = tokenize_data(
    df_test, df_test[NUMERICAL_FEATURES].values)

# %%
# create the custom datasets with numerical features
train_dataset = TextDataset(train_encodings, train_labels, train_numerical_features)
val_dataset = TextDataset(val_encodings, val_labels, val_numerical_features)
test_dataset = TextDataset(test_encodings, test_labels, test_numerical_features)

# %%
# create the data loaders
batch_size = 32
train_loader, val_loader, test_loader = create_data_loaders(train_dataset, 
                                                            val_dataset, 
                                                            test_dataset, 
                                                            batch_size)

# %%
# create the RedditRegression model instance and move it to the device
model = RedditRegression(num_numerical_features=len(NUMERICAL_FEATURES)).to(device)

# freeze the pre-trained weights
for param in model.bert.parameters():
    param.requires_grad = False

# define the loss function (Huber)
loss_fn = nn.SmoothL1Loss(reduction='mean')

# define the optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=.01)

# define the scheduler
scheduler = StepLR(optimizer, step_size=3, gamma=0.1)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
num_epochs = 10
original_scale = False
for epoch in tqdm(range(num_epochs), desc='Epochs'):
    if epoch > 4:
        original_scale = True
    # train
    train_loss, train_mae, train_mape = train(model,
                                              train_loader, 
                                              loss_fn, 
                                              optimizer, 
                                              original_scale)
    print(
        f'Epoch {epoch+1}, Train Loss: {train_loss}, Train MAE: {train_mae}, Train MAPE: {train_mape}')
    scheduler.step()

    # evaluation on validation set
    val_loss, val_mae, val_mape, val_labels, val_yhats = evaluate(model,
                                                                  val_loader,
                                                                  loss_fn,
                                                                  original_scale)
    print(
        f'Epoch {epoch+1}, Val Loss: {val_loss}, Val MAE: {val_mae}, Val MAPE: {val_mape}')

    # evaluation on test set
    test_loss, test_mae, test_mape, test_labels, test_yhats = evaluate(model, 
                                                                       test_loader, 
                                                                       loss_fn, 
                                                                       original_scale)
    print(
        f'Epoch {epoch+1}, Test Loss: {test_loss}, Test MAE: {test_mae}, Test MAPE: {test_mape}')
# Out:
# Epochs:   0%|                                            | 0/10 [00:00<?, ?it/s]
# Training:   0%|                                          | 0/95 [00:00<?, ?it/s]
# Training:   0%|          | 0/95 [00:04<?, ?it/s, Loss=11.2, MAE=11.6, MAPE=3.47]
# Training:   1%|  | 1/95 [00:04<06:53,  4.40s/it, Loss=11.2, MAE=11.6, MAPE=3.47]
# Training:   1%|     | 1/95 [00:08<06:53,  4.40s/it, Loss=369, MAE=370, MAPE=141]
# Training:   2%|     | 2/95 [00:08<06:29,  4.19s/it, Loss=369, MAE=370, MAPE=141]
# Training:   2%|  | 2/95 [00:12<06:29,  4.19s/it, Loss=20.7, MAE=21.2, MAPE=29.5]
# Training:   3%|  | 3/95 [00:12<06:19,  4.12s/it, Loss=20.7, MAE=21.2, MAPE=29.5]
# Training:   3%|  | 3/95 [00:16<06:19,  4.12s/it, Loss=43.7, MAE=44.2, MAPE=21.5]
# Training:   4%|  | 4/95 [00:16<06:12,  4.09s/it, Loss=43.7, MAE=44.2, MAPE=21.5]
# Training:   4%|  | 4/95 [00:20<06:12,  4.09s/it, Loss=42.5, MAE=42.9, MAPE=11.7]
# Training:   5%|  | 5/95 [00:20<06:06,  4.07s/it, Loss=42.5, MAE=42.9, MAPE=11.7]
# Training:   5%|  | 5/95 [00:24<06:06,  4.07s/it, Loss=5.79, MAE=6.28, MAPE=4.87]
# Training:   6%|▏ | 6/95 [00:24<06:01,  4.06s/it, Loss=5.79, MAE=6.28, MAPE=4.87]
# Training:   6%|▏ | 6/95 [00:28<06:01,  4.06s/it, Loss=10.3, MAE=10.8, MAPE=9.26]
# Training:   7%|▏ | 7/95 [00:28<05:57,  4.06s/it, Loss=10.3, MAE=10.8, MAPE=9.26]
# Training:   7%|▏ | 7/95 [00:32<05:57,  4.06s/it, Loss=3.04, MAE=3.52, MAPE=1.85]
# Training:   8%|▏ | 8/95 [00:32<05:52,  4.05s/it, Loss=3.04, MAE=3.52, MAPE=1.85]
# Training:   8%|▏ | 8/95 [00:36<05:52,  4.05s/it, Loss=10.4, MAE=10.8, MAPE=4.05]
# Training:   9%|▏ | 9/95 [00:36<05:48,  4.05s/it, Loss=10.4, MAE=10.8, MAPE=4.05]
# Training:   9%|▍   | 9/95 [00:40<05:48,  4.05s/it, Loss=10.6, MAE=11, MAPE=3.29]
# Training:  11%|▎  | 10/95 [00:40<05:44,  4.05s/it, Loss=10.6, MAE=11, MAPE=3.29]
# Training:  11%| | 10/95 [00:44<05:44,  4.05s/it, Loss=2.87, MAE=3.28, MAPE=1.55]
# Training:  12%| | 11/95 [00:44<05:40,  4.05s/it, Loss=2.87, MAE=3.28, MAPE=1.55]
# Training:  12%| | 11/95 [00:48<05:40,  4.05s/it, Loss=2.26, MAE=2.72, MAPE=1.73]
# Training:  13%|▏| 12/95 [00:48<05:36,  4.05s/it, Loss=2.26, MAE=2.72, MAPE=1.73]
# Training:  13%|▎ | 12/95 [00:52<05:36,  4.05s/it, Loss=1.3, MAE=1.72, MAPE=1.55]
# Training:  14%|▎ | 13/95 [00:52<05:31,  4.05s/it, Loss=1.3, MAE=1.72, MAPE=1.55]
# Training:  14%|▏| 13/95 [00:56<05:31,  4.05s/it, Loss=1.24, MAE=1.64, MAPE=1.32]
# Training:  15%|▏| 14/95 [00:56<05:27,  4.05s/it, Loss=1.24, MAE=1.64, MAPE=1.32]
# Training:  15%|▎ | 14/95 [01:01<05:27,  4.05s/it, Loss=1.18, MAE=1.57, MAPE=1.4]
# Training:  16%|▎ | 15/95 [01:01<05:23,  4.04s/it, Loss=1.18, MAE=1.57, MAPE=1.4]
# Training:  16%|▏| 15/95 [01:05<05:23,  4.04s/it, Loss=0.973, MAE=1.35, MAPE=1.07
# Training:  17%|▏| 16/95 [01:05<05:19,  4.04s/it, Loss=0.973, MAE=1.35, MAPE=1.07
# Training:  17%|▏| 16/95 [01:09<05:19,  4.04s/it, Loss=1.39, MAE=1.82, MAPE=1.92]
# Training:  18%|▏| 17/95 [01:09<05:15,  4.04s/it, Loss=1.39, MAE=1.82, MAPE=1.92]
# Training:  18%|▏| 17/95 [01:13<05:15,  4.04s/it, Loss=1.63, MAE=2.08, MAPE=2.27]
# Training:  19%|▏| 18/95 [01:13<05:11,  4.04s/it, Loss=1.63, MAE=2.08, MAPE=2.27]
# Training:  19%|▏| 18/95 [01:17<05:11,  4.04s/it, Loss=1.32, MAE=1.73, MAPE=1.98]
# Training:  20%|▏| 19/95 [01:17<05:07,  4.04s/it, Loss=1.32, MAE=1.73, MAPE=1.98]
# Training:  20%|▏| 19/95 [01:21<05:07,  4.04s/it, Loss=0.917, MAE=1.32, MAPE=1.06
# Training:  21%|▏| 20/95 [01:21<05:03,  4.04s/it, Loss=0.917, MAE=1.32, MAPE=1.06
# Training:  21%|▏| 20/95 [01:25<05:03,  4.04s/it, Loss=2.54, MAE=2.95, MAPE=1.15]
# Training:  22%|▏| 21/95 [01:25<04:59,  4.04s/it, Loss=2.54, MAE=2.95, MAPE=1.15]
# Training:  22%|▏| 21/95 [01:29<04:59,  4.04s/it, Loss=1.02, MAE=1.46, MAPE=0.751
# Training:  23%|▏| 22/95 [01:29<04:55,  4.05s/it, Loss=1.02, MAE=1.46, MAPE=0.751
# Training:  23%|▏| 22/95 [01:33<04:55,  4.05s/it, Loss=2.51, MAE=2.96, MAPE=5.56]
# Training:  24%|▏| 23/95 [01:33<04:51,  4.05s/it, Loss=2.51, MAE=2.96, MAPE=5.56]
# Training:  24%|▏| 23/95 [01:37<04:51,  4.05s/it, Loss=2.06, MAE=2.53, MAPE=3.74]
# Training:  25%|▎| 24/95 [01:37<04:47,  4.05s/it, Loss=2.06, MAE=2.53, MAPE=3.74]
# Training:  25%|▎| 24/95 [01:41<04:47,  4.05s/it, Loss=1.93, MAE=2.38, MAPE=2.56]
# Training:  26%|▎| 25/95 [01:41<04:43,  4.05s/it, Loss=1.93, MAE=2.38, MAPE=2.56]
# Training:  26%|▎| 25/95 [01:45<04:43,  4.05s/it, Loss=2.63, MAE=3.06, MAPE=1.68]
# Training:  27%|▎| 26/95 [01:45<04:40,  4.06s/it, Loss=2.63, MAE=3.06, MAPE=1.68]
# Training:  27%|▎| 26/95 [01:49<04:40,  4.06s/it, Loss=1.42, MAE=1.86, MAPE=1.64]
# Training:  28%|▎| 27/95 [01:49<04:36,  4.07s/it, Loss=1.42, MAE=1.86, MAPE=1.64]
# Training:  28%|▎| 27/95 [01:53<04:36,  4.07s/it, Loss=2.54, MAE=2.99, MAPE=1.76]
# Training:  29%|▎| 28/95 [01:53<04:32,  4.06s/it, Loss=2.54, MAE=2.99, MAPE=1.76]
# Training:  29%|▎| 28/95 [01:57<04:32,  4.06s/it, Loss=1.57, MAE=2.01, MAPE=2.04]
# Training:  31%|▎| 29/95 [01:57<04:28,  4.07s/it, Loss=1.57, MAE=2.01, MAPE=2.04]
# Training:  31%|▎| 29/95 [02:01<04:28,  4.07s/it, Loss=1.37, MAE=1.8, MAPE=0.897]
# Training:  32%|▎| 30/95 [02:01<04:24,  4.07s/it, Loss=1.37, MAE=1.8, MAPE=0.897]
# Training:  32%|▎| 30/95 [02:05<04:24,  4.07s/it, Loss=1.66, MAE=2.12, MAPE=0.966
# Training:  33%|▎| 31/95 [02:05<04:20,  4.07s/it, Loss=1.66, MAE=2.12, MAPE=0.966
# Training:  33%|▎| 31/95 [02:09<04:20,  4.07s/it, Loss=1.42, MAE=1.81, MAPE=1.08]
# Training:  34%|▎| 32/95 [02:09<04:16,  4.07s/it, Loss=1.42, MAE=1.81, MAPE=1.08]
# Training:  34%|▎| 32/95 [02:14<04:16,  4.07s/it, Loss=1.09, MAE=1.51, MAPE=0.946
# Training:  35%|▎| 33/95 [02:14<04:12,  4.07s/it, Loss=1.09, MAE=1.51, MAPE=0.946
# Training:  35%|▎| 33/95 [02:18<04:12,  4.07s/it, Loss=1.09, MAE=1.5, MAPE=0.981]
# Training:  36%|▎| 34/95 [02:18<04:08,  4.07s/it, Loss=1.09, MAE=1.5, MAPE=0.981]
# Training:  36%|▎| 34/95 [02:22<04:08,  4.07s/it, Loss=1.14, MAE=1.59, MAPE=1.16]
# Training:  37%|▎| 35/95 [02:22<04:04,  4.07s/it, Loss=1.14, MAE=1.59, MAPE=1.16]
# Training:  37%|▎| 35/95 [02:26<04:04,  4.07s/it, Loss=1.41, MAE=1.86, MAPE=2.26]
# Training:  38%|▍| 36/95 [02:26<04:00,  4.07s/it, Loss=1.41, MAE=1.86, MAPE=2.26]
# Training:  38%|▍| 36/95 [02:30<04:00,  4.07s/it, Loss=0.896, MAE=1.34, MAPE=1.49
# Training:  39%|▍| 37/95 [02:30<03:56,  4.07s/it, Loss=0.896, MAE=1.34, MAPE=1.49
# Training:  39%|▍| 37/95 [02:34<03:56,  4.07s/it, Loss=1.05, MAE=1.48, MAPE=1.29]
# Training:  40%|▍| 38/95 [02:34<03:52,  4.07s/it, Loss=1.05, MAE=1.48, MAPE=1.29]
# Training:  40%|▍| 38/95 [02:38<03:52,  4.07s/it, Loss=1.09, MAE=1.55, MAPE=2.23]
# Training:  41%|▍| 39/95 [02:38<03:48,  4.08s/it, Loss=1.09, MAE=1.55, MAPE=2.23]
# Training:  41%|▍| 39/95 [02:42<03:48,  4.08s/it, Loss=1.34, MAE=1.75, MAPE=1.44]
# Training:  42%|▍| 40/95 [02:42<03:44,  4.08s/it, Loss=1.34, MAE=1.75, MAPE=1.44]
# Training:  42%|█▋  | 40/95 [02:46<03:44,  4.08s/it, Loss=1.51, MAE=2, MAPE=1.51]
# Training:  43%|█▋  | 41/95 [02:46<03:40,  4.08s/it, Loss=1.51, MAE=2, MAPE=1.51]
# Training:  43%|▊ | 41/95 [02:50<03:40,  4.08s/it, Loss=0.985, MAE=1.4, MAPE=1.4]
# Training:  44%|▉ | 42/95 [02:50<03:36,  4.08s/it, Loss=0.985, MAE=1.4, MAPE=1.4]
# Training:  44%|▍| 42/95 [02:54<03:36,  4.08s/it, Loss=1.39, MAE=1.86, MAPE=2.07]
# Training:  45%|▍| 43/95 [02:54<03:31,  4.08s/it, Loss=1.39, MAE=1.86, MAPE=2.07]
# Training:  45%|▍| 43/95 [02:58<03:31,  4.08s/it, Loss=0.885, MAE=1.25, MAPE=1.14
# Training:  46%|▍| 44/95 [02:58<03:28,  4.08s/it, Loss=0.885, MAE=1.25, MAPE=1.14
# Training:  46%|▍| 44/95 [03:03<03:28,  4.08s/it, Loss=0.954, MAE=1.43, MAPE=2.13
# Training:  47%|▍| 45/95 [03:03<03:24,  4.10s/it, Loss=0.954, MAE=1.43, MAPE=2.13
# Training:  47%|█▍ | 45/95 [03:07<03:24,  4.10s/it, Loss=1.26, MAE=1.7, MAPE=1.9]
# Training:  48%|█▍ | 46/95 [03:07<03:20,  4.09s/it, Loss=1.26, MAE=1.7, MAPE=1.9]
# Training:  48%|▍| 46/95 [03:11<03:20,  4.09s/it, Loss=1.26, MAE=1.67, MAPE=1.14]
# Training:  49%|▍| 47/95 [03:11<03:16,  4.09s/it, Loss=1.26, MAE=1.67, MAPE=1.14]
# Training:  49%|▍| 47/95 [03:15<03:16,  4.09s/it, Loss=1.18, MAE=1.61, MAPE=1.51]
# Training:  51%|▌| 48/95 [03:15<03:11,  4.08s/it, Loss=1.18, MAE=1.61, MAPE=1.51]
# Training:  51%|█ | 48/95 [03:19<03:11,  4.08s/it, Loss=1.2, MAE=1.64, MAPE=3.06]
# Training:  52%|█ | 49/95 [03:19<03:08,  4.09s/it, Loss=1.2, MAE=1.64, MAPE=3.06]
# Training:  52%|▌| 49/95 [03:23<03:08,  4.09s/it, Loss=1.38, MAE=1.81, MAPE=1.51]
# Training:  53%|▌| 50/95 [03:23<03:03,  4.08s/it, Loss=1.38, MAE=1.81, MAPE=1.51]
# Training:  53%|█ | 50/95 [03:27<03:03,  4.08s/it, Loss=1.35, MAE=1.79, MAPE=1.3]
# Training:  54%|█ | 51/95 [03:27<02:59,  4.08s/it, Loss=1.35, MAE=1.79, MAPE=1.3]
# Training:  54%|▌| 51/95 [03:31<02:59,  4.08s/it, Loss=1.39, MAE=1.81, MAPE=1.21]
# Training:  55%|▌| 52/95 [03:31<02:55,  4.09s/it, Loss=1.39, MAE=1.81, MAPE=1.21]
# Training:  55%|▌| 52/95 [03:35<02:55,  4.09s/it, Loss=1.32, MAE=1.74, MAPE=1.14]
# Training:  56%|▌| 53/95 [03:35<02:51,  4.09s/it, Loss=1.32, MAE=1.74, MAPE=1.14]
# Training:  56%|▌| 53/95 [03:39<02:51,  4.09s/it, Loss=1.12, MAE=1.52, MAPE=1.12]
# Training:  57%|▌| 54/95 [03:39<02:47,  4.09s/it, Loss=1.12, MAE=1.52, MAPE=1.12]
# Training:  57%|▌| 54/95 [03:43<02:47,  4.09s/it, Loss=0.845, MAE=1.27, MAPE=1.74
# Training:  58%|▌| 55/95 [03:43<02:43,  4.09s/it, Loss=0.845, MAE=1.27, MAPE=1.74
# Training:  58%|█▏| 55/95 [03:47<02:43,  4.09s/it, Loss=1.14, MAE=1.6, MAPE=2.96]
# Training:  59%|█▏| 56/95 [03:47<02:39,  4.08s/it, Loss=1.14, MAE=1.6, MAPE=2.96]
# Training:  59%|▌| 56/95 [03:52<02:39,  4.08s/it, Loss=1.25, MAE=1.68, MAPE=2.13]
# Training:  60%|▌| 57/95 [03:52<02:35,  4.09s/it, Loss=1.25, MAE=1.68, MAPE=2.13]
# Training:  60%|▌| 57/95 [03:56<02:35,  4.09s/it, Loss=1.16, MAE=1.62, MAPE=1.55]
# Training:  61%|▌| 58/95 [03:56<02:31,  4.09s/it, Loss=1.16, MAE=1.62, MAPE=1.55]
# Training:  61%|▌| 58/95 [04:00<02:31,  4.09s/it, Loss=1.26, MAE=1.71, MAPE=1.76]
# Training:  62%|▌| 59/95 [04:00<02:27,  4.09s/it, Loss=1.26, MAE=1.71, MAPE=1.76]
# Training:  62%|▌| 59/95 [04:04<02:27,  4.09s/it, Loss=1.29, MAE=1.73, MAPE=1.59]
# Training:  63%|▋| 60/95 [04:04<02:23,  4.09s/it, Loss=1.29, MAE=1.73, MAPE=1.59]
# Training:  63%|▋| 60/95 [04:08<02:23,  4.09s/it, Loss=1.11, MAE=1.52, MAPE=1.33]
# Training:  64%|▋| 61/95 [04:08<02:18,  4.09s/it, Loss=1.11, MAE=1.52, MAPE=1.33]
# Training:  64%|▋| 61/95 [04:12<02:18,  4.09s/it, Loss=1.14, MAE=1.54, MAPE=1.58]
# Training:  65%|▋| 62/95 [04:12<02:14,  4.09s/it, Loss=1.14, MAE=1.54, MAPE=1.58]
# Training:  65%|▋| 62/95 [04:16<02:14,  4.09s/it, Loss=0.908, MAE=1.31, MAPE=1.29
# Training:  66%|▋| 63/95 [04:16<02:10,  4.09s/it, Loss=0.908, MAE=1.31, MAPE=1.29
# Training:  66%|▋| 63/95 [04:20<02:10,  4.09s/it, Loss=1.21, MAE=1.61, MAPE=0.988
# Training:  67%|▋| 64/95 [04:20<02:07,  4.10s/it, Loss=1.21, MAE=1.61, MAPE=0.988
# Training:  67%|▋| 64/95 [04:24<02:07,  4.10s/it, Loss=0.86, MAE=1.26, MAPE=1.14]
# Training:  68%|▋| 65/95 [04:24<02:03,  4.10s/it, Loss=0.86, MAE=1.26, MAPE=1.14]
# Training:  68%|▋| 65/95 [04:28<02:03,  4.10s/it, Loss=1.49, MAE=1.92, MAPE=1.57]
# Training:  69%|▋| 66/95 [04:28<01:59,  4.11s/it, Loss=1.49, MAE=1.92, MAPE=1.57]
# Training:  69%|▋| 66/95 [04:33<01:59,  4.11s/it, Loss=1.05, MAE=1.46, MAPE=1.28]
# Training:  71%|▋| 67/95 [04:33<01:54,  4.10s/it, Loss=1.05, MAE=1.46, MAPE=1.28]
# Training:  71%|▋| 67/95 [04:37<01:54,  4.10s/it, Loss=1.25, MAE=1.67, MAPE=2.15]
# Training:  72%|▋| 68/95 [04:37<01:50,  4.11s/it, Loss=1.25, MAE=1.67, MAPE=2.15]
# Training:  72%|▋| 68/95 [04:41<01:50,  4.11s/it, Loss=1.42, MAE=1.86, MAPE=2.97]
# Training:  73%|▋| 69/95 [04:41<01:46,  4.11s/it, Loss=1.42, MAE=1.86, MAPE=2.97]
# Training:  73%|▋| 69/95 [04:45<01:46,  4.11s/it, Loss=0.99, MAE=1.46, MAPE=1.92]
# Training:  74%|▋| 70/95 [04:45<01:42,  4.11s/it, Loss=0.99, MAE=1.46, MAPE=1.92]
# Training:  74%|▋| 70/95 [04:49<01:42,  4.11s/it, Loss=1.23, MAE=1.68, MAPE=2.07]
# Training:  75%|▋| 71/95 [04:49<01:38,  4.12s/it, Loss=1.23, MAE=1.68, MAPE=2.07]
# Training:  75%|▋| 71/95 [04:53<01:38,  4.12s/it, Loss=0.826, MAE=1.25, MAPE=0.72
# Training:  76%|▊| 72/95 [04:53<01:34,  4.12s/it, Loss=0.826, MAE=1.25, MAPE=0.72
# Training:  76%|▊| 72/95 [04:57<01:34,  4.12s/it, Loss=0.84, MAE=1.23, MAPE=2.11]
# Training:  77%|▊| 73/95 [04:57<01:30,  4.12s/it, Loss=0.84, MAE=1.23, MAPE=2.11]
# Training:  77%|▊| 73/95 [05:01<01:30,  4.12s/it, Loss=1.24, MAE=1.68, MAPE=1.32]
# Training:  78%|▊| 74/95 [05:01<01:26,  4.12s/it, Loss=1.24, MAE=1.68, MAPE=1.32]
# Training:  78%|▊| 74/95 [05:06<01:26,  4.12s/it, Loss=1.19, MAE=1.62, MAPE=1.71]
# Training:  79%|▊| 75/95 [05:06<01:22,  4.12s/it, Loss=1.19, MAE=1.62, MAPE=1.71]
# Training:  79%|▊| 75/95 [05:10<01:22,  4.12s/it, Loss=1.21, MAE=1.66, MAPE=1.76]
# Training:  80%|▊| 76/95 [05:10<01:18,  4.12s/it, Loss=1.21, MAE=1.66, MAPE=1.76]
# Training:  80%|▊| 76/95 [05:14<01:18,  4.12s/it, Loss=1.12, MAE=1.52, MAPE=0.873
# Training:  81%|▊| 77/95 [05:14<01:14,  4.12s/it, Loss=1.12, MAE=1.52, MAPE=0.873
# Training:  81%|▊| 77/95 [05:18<01:14,  4.12s/it, Loss=1.15, MAE=1.54, MAPE=0.917
# Training:  82%|▊| 78/95 [05:18<01:10,  4.12s/it, Loss=1.15, MAE=1.54, MAPE=0.917
# Training:  82%|▊| 78/95 [05:22<01:10,  4.12s/it, Loss=1.04, MAE=1.44, MAPE=1.55]
# Training:  83%|▊| 79/95 [05:22<01:06,  4.13s/it, Loss=1.04, MAE=1.44, MAPE=1.55]
# Training:  83%|█▋| 79/95 [05:26<01:06,  4.13s/it, Loss=1.26, MAE=1.7, MAPE=1.26]
# Training:  84%|█▋| 80/95 [05:26<01:01,  4.13s/it, Loss=1.26, MAE=1.7, MAPE=1.26]
# Training:  84%|▊| 80/95 [05:30<01:01,  4.13s/it, Loss=1.03, MAE=1.46, MAPE=2.87]
# Training:  85%|▊| 81/95 [05:30<00:57,  4.13s/it, Loss=1.03, MAE=1.46, MAPE=2.87]
# Training:  85%|▊| 81/95 [05:34<00:57,  4.13s/it, Loss=1.12, MAE=1.58, MAPE=1.67]
# Training:  86%|▊| 82/95 [05:34<00:53,  4.13s/it, Loss=1.12, MAE=1.58, MAPE=1.67]
# Training:  86%|▊| 82/95 [05:39<00:53,  4.13s/it, Loss=1.03, MAE=1.47, MAPE=1.84]
# Training:  87%|▊| 83/95 [05:39<00:49,  4.13s/it, Loss=1.03, MAE=1.47, MAPE=1.84]
# Training:  87%|██▌| 83/95 [05:43<00:49,  4.13s/it, Loss=1.1, MAE=1.57, MAPE=2.4]
# Training:  88%|██▋| 84/95 [05:43<00:45,  4.14s/it, Loss=1.1, MAE=1.57, MAPE=2.4]
# Training:  88%|▉| 84/95 [05:47<00:45,  4.14s/it, Loss=0.972, MAE=1.42, MAPE=3.18
# Training:  89%|▉| 85/95 [05:47<00:41,  4.13s/it, Loss=0.972, MAE=1.42, MAPE=3.18
# Training:  89%|▉| 85/95 [05:51<00:41,  4.13s/it, Loss=1.09, MAE=1.54, MAPE=2.34]
# Training:  91%|▉| 86/95 [05:51<00:37,  4.14s/it, Loss=1.09, MAE=1.54, MAPE=2.34]
# Training:  91%|▉| 86/95 [05:55<00:37,  4.14s/it, Loss=1.19, MAE=1.66, MAPE=1.32]
# Training:  92%|▉| 87/95 [05:55<00:33,  4.13s/it, Loss=1.19, MAE=1.66, MAPE=1.32]
# Training:  92%|█▊| 87/95 [05:59<00:33,  4.13s/it, Loss=1.05, MAE=1.5, MAPE=2.51]
# Training:  93%|█▊| 88/95 [05:59<00:28,  4.14s/it, Loss=1.05, MAE=1.5, MAPE=2.51]
# Training:  93%|▉| 88/95 [06:03<00:28,  4.14s/it, Loss=0.95, MAE=1.38, MAPE=1.33]
# Training:  94%|▉| 89/95 [06:03<00:24,  4.14s/it, Loss=0.95, MAE=1.38, MAPE=1.33]
# Training:  94%|█▊| 89/95 [06:07<00:24,  4.14s/it, Loss=1.2, MAE=1.65, MAPE=1.78]
# Training:  95%|█▉| 90/95 [06:07<00:20,  4.13s/it, Loss=1.2, MAE=1.65, MAPE=1.78]
# Training:  95%|█▉| 90/95 [06:12<00:20,  4.13s/it, Loss=1.12, MAE=1.6, MAPE=2.42]
# Training:  96%|█▉| 91/95 [06:12<00:16,  4.14s/it, Loss=1.12, MAE=1.6, MAPE=2.42]
# Training:  96%|▉| 91/95 [06:16<00:16,  4.14s/it, Loss=1.29, MAE=1.75, MAPE=1.85]
# Training:  97%|▉| 92/95 [06:16<00:12,  4.13s/it, Loss=1.29, MAE=1.75, MAPE=1.85]
# Training:  97%|█▉| 92/95 [06:20<00:12,  4.13s/it, Loss=1.2, MAE=1.68, MAPE=3.27]
# Training:  98%|█▉| 93/95 [06:20<00:08,  4.13s/it, Loss=1.2, MAE=1.68, MAPE=3.27]
# Training:  98%|▉| 93/95 [06:24<00:08,  4.13s/it, Loss=0.99, MAE=1.45, MAPE=1.49]
# Training:  99%|▉| 94/95 [06:24<00:04,  4.14s/it, Loss=0.99, MAE=1.45, MAPE=1.49]
# Training:  99%|█▉| 94/95 [06:28<00:04,  4.14s/it, Loss=1.28, MAE=1.78, MAPE=1.9]
# Training: 100%|██| 95/95 [06:28<00:00,  4.05s/it, Loss=1.28, MAE=1.78, MAPE=1.9]
# Epoch 1, Train Loss: 6.709235147426003, Train MAE: 7.147599697113037, Train MAPE: 3.98036527633667
# Evaluation:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Evaluation:   0%|       | 0/17 [00:03<?, ?it/s, Loss=0.949, MAE=1.43, MAPE=2.08]
# Evaluation:   6%| | 1/17 [00:03<00:48,  3.05s/it, Loss=0.949, MAE=1.43, MAPE=2.0
# Evaluation:   6%| | 1/17 [00:06<00:48,  3.05s/it, Loss=1.21, MAE=1.69, MAPE=1.96
# Evaluation:  12%| | 2/17 [00:06<00:46,  3.07s/it, Loss=1.21, MAE=1.69, MAPE=1.96
# Evaluation:  12%| | 2/17 [00:09<00:46,  3.07s/it, Loss=1.18, MAE=1.67, MAPE=2.05
# Evaluation:  18%|▏| 3/17 [00:09<00:43,  3.08s/it, Loss=1.18, MAE=1.67, MAPE=2.05
# Evaluation:  18%|▏| 3/17 [00:12<00:43,  3.08s/it, Loss=0.858, MAE=1.3, MAPE=1.07
# Evaluation:  24%|▏| 4/17 [00:12<00:40,  3.09s/it, Loss=0.858, MAE=1.3, MAPE=1.07
# Evaluation:  24%|▏| 4/17 [00:15<00:40,  3.09s/it, Loss=1.11, MAE=1.59, MAPE=2.14
# Evaluation:  29%|▎| 5/17 [00:15<00:37,  3.09s/it, Loss=1.11, MAE=1.59, MAPE=2.14
# Evaluation:  29%|▎| 5/17 [00:18<00:37,  3.09s/it, Loss=0.976, MAE=1.41, MAPE=1.7
# Evaluation:  35%|▎| 6/17 [00:18<00:34,  3.09s/it, Loss=0.976, MAE=1.41, MAPE=1.7
# Evaluation:  35%|▎| 6/17 [00:21<00:34,  3.09s/it, Loss=1.09, MAE=1.56, MAPE=1.7]
# Evaluation:  41%|▍| 7/17 [00:21<00:30,  3.10s/it, Loss=1.09, MAE=1.56, MAPE=1.7]
# Evaluation:  41%|▍| 7/17 [00:24<00:30,  3.10s/it, Loss=1.04, MAE=1.5, MAPE=1.75]
# Evaluation:  47%|▍| 8/17 [00:24<00:27,  3.10s/it, Loss=1.04, MAE=1.5, MAPE=1.75]
# Evaluation:  47%|▍| 8/17 [00:27<00:27,  3.10s/it, Loss=0.962, MAE=1.42, MAPE=2.0
# Evaluation:  53%|▌| 9/17 [00:27<00:24,  3.10s/it, Loss=0.962, MAE=1.42, MAPE=2.0
# Evaluation:  53%|▌| 9/17 [00:30<00:24,  3.10s/it, Loss=1.13, MAE=1.6, MAPE=2.01]
# Evaluation:  59%|▌| 10/17 [00:30<00:21,  3.10s/it, Loss=1.13, MAE=1.6, MAPE=2.01
# Evaluation:  59%|▌| 10/17 [00:34<00:21,  3.10s/it, Loss=1.12, MAE=1.59, MAPE=1.5
# Evaluation:  65%|▋| 11/17 [00:34<00:18,  3.11s/it, Loss=1.12, MAE=1.59, MAPE=1.5
# Evaluation:  65%|▋| 11/17 [00:37<00:18,  3.11s/it, Loss=1.03, MAE=1.48, MAPE=1.8
# Evaluation:  71%|▋| 12/17 [00:37<00:15,  3.11s/it, Loss=1.03, MAE=1.48, MAPE=1.8
# Evaluation:  71%|▋| 12/17 [00:40<00:15,  3.11s/it, Loss=0.982, MAE=1.42, MAPE=1.
# Evaluation:  76%|▊| 13/17 [00:40<00:12,  3.11s/it, Loss=0.982, MAE=1.42, MAPE=1.
# Evaluation:  76%|▊| 13/17 [00:43<00:12,  3.11s/it, Loss=1.1, MAE=1.56, MAPE=1.37
# Evaluation:  82%|▊| 14/17 [00:43<00:09,  3.11s/it, Loss=1.1, MAE=1.56, MAPE=1.37
# Evaluation:  82%|▊| 14/17 [00:46<00:09,  3.11s/it, Loss=0.779, MAE=1.24, MAPE=1.
# Evaluation:  88%|▉| 15/17 [00:46<00:06,  3.11s/it, Loss=0.779, MAE=1.24, MAPE=1.
# Evaluation:  88%|█▊| 15/17 [00:49<00:06,  3.11s/it, Loss=1, MAE=1.46, MAPE=1.08]
# Evaluation:  94%|█▉| 16/17 [00:49<00:03,  3.10s/it, Loss=1, MAE=1.46, MAPE=1.08]
# Evaluation:  94%|▉| 16/17 [00:52<00:03,  3.10s/it, Loss=1.28, MAE=1.77, MAPE=2.9
# Evaluation: 100%|█| 17/17 [00:52<00:00,  2.92s/it, Loss=1.28, MAE=1.77, MAPE=2.9
# Epoch 1, Val Loss: 1.047254502773285, Val MAE: 1.510587215423584, Val MAPE: 1.8130682706832886
# Evaluation:   0%|                                        | 0/20 [00:00<?, ?it/s]
# Evaluation:   0%|        | 0/20 [00:03<?, ?it/s, Loss=0.94, MAE=1.36, MAPE=2.26]
# Evaluation:   5%| | 1/20 [00:03<00:58,  3.10s/it, Loss=0.94, MAE=1.36, MAPE=2.26
# Evaluation:   5%| | 1/20 [00:06<00:58,  3.10s/it, Loss=0.944, MAE=1.39, MAPE=2.1
# Evaluation:  10%| | 2/20 [00:06<00:55,  3.10s/it, Loss=0.944, MAE=1.39, MAPE=2.1
# Evaluation:  10%| | 2/20 [00:09<00:55,  3.10s/it, Loss=0.988, MAE=1.45, MAPE=1.9
# Evaluation:  15%|▏| 3/20 [00:09<00:52,  3.10s/it, Loss=0.988, MAE=1.45, MAPE=1.9
# Evaluation:  15%|▏| 3/20 [00:12<00:52,  3.10s/it, Loss=0.971, MAE=1.43, MAPE=1.8
# Evaluation:  20%|▏| 4/20 [00:12<00:49,  3.12s/it, Loss=0.971, MAE=1.43, MAPE=1.8
# Evaluation:  20%|▏| 4/20 [00:15<00:49,  3.12s/it, Loss=1.09, MAE=1.56, MAPE=2.07
# Evaluation:  25%|▎| 5/20 [00:15<00:46,  3.11s/it, Loss=1.09, MAE=1.56, MAPE=2.07
# Evaluation:  25%|▎| 5/20 [00:18<00:46,  3.11s/it, Loss=1.06, MAE=1.5, MAPE=2.21]
# Evaluation:  30%|▎| 6/20 [00:18<00:43,  3.11s/it, Loss=1.06, MAE=1.5, MAPE=2.21]
# Evaluation:  30%|▎| 6/20 [00:21<00:43,  3.11s/it, Loss=1.11, MAE=1.56, MAPE=1.42
# Evaluation:  35%|▎| 7/20 [00:21<00:40,  3.11s/it, Loss=1.11, MAE=1.56, MAPE=1.42
# Evaluation:  35%|▎| 7/20 [00:24<00:40,  3.11s/it, Loss=0.931, MAE=1.38, MAPE=1.2
# Evaluation:  40%|▍| 8/20 [00:24<00:37,  3.11s/it, Loss=0.931, MAE=1.38, MAPE=1.2
# Evaluation:  40%|▍| 8/20 [00:27<00:37,  3.11s/it, Loss=0.966, MAE=1.41, MAPE=2.0
# Evaluation:  45%|▍| 9/20 [00:27<00:34,  3.11s/it, Loss=0.966, MAE=1.41, MAPE=2.0
# Evaluation:  45%|▍| 9/20 [00:31<00:34,  3.11s/it, Loss=1.09, MAE=1.55, MAPE=1.42
# Evaluation:  50%|▌| 10/20 [00:31<00:31,  3.11s/it, Loss=1.09, MAE=1.55, MAPE=1.4
# Evaluation:  50%|▌| 10/20 [00:34<00:31,  3.11s/it, Loss=0.986, MAE=1.46, MAPE=2.
# Evaluation:  55%|▌| 11/20 [00:34<00:27,  3.11s/it, Loss=0.986, MAE=1.46, MAPE=2.
# Evaluation:  55%|▌| 11/20 [00:37<00:27,  3.11s/it, Loss=1.16, MAE=1.62, MAPE=0.9
# Evaluation:  60%|▌| 12/20 [00:37<00:24,  3.11s/it, Loss=1.16, MAE=1.62, MAPE=0.9
# Evaluation:  60%|▌| 12/20 [00:40<00:24,  3.11s/it, Loss=0.827, MAE=1.28, MAPE=1.
# Evaluation:  65%|▋| 13/20 [00:40<00:21,  3.11s/it, Loss=0.827, MAE=1.28, MAPE=1.
# Evaluation:  65%|▋| 13/20 [00:43<00:21,  3.11s/it, Loss=1.12, MAE=1.57, MAPE=2.3
# Evaluation:  70%|▋| 14/20 [00:43<00:18,  3.11s/it, Loss=1.12, MAE=1.57, MAPE=2.3
# Evaluation:  70%|▋| 14/20 [00:46<00:18,  3.11s/it, Loss=0.944, MAE=1.4, MAPE=2.6
# Evaluation:  75%|▊| 15/20 [00:46<00:15,  3.11s/it, Loss=0.944, MAE=1.4, MAPE=2.6
# Evaluation:  75%|▊| 15/20 [00:49<00:15,  3.11s/it, Loss=0.811, MAE=1.26, MAPE=1.
# Evaluation:  80%|▊| 16/20 [00:49<00:12,  3.12s/it, Loss=0.811, MAE=1.26, MAPE=1.
# Evaluation:  80%|▊| 16/20 [00:52<00:12,  3.12s/it, Loss=1.22, MAE=1.67, MAPE=2.6
# Evaluation:  85%|▊| 17/20 [00:52<00:09,  3.12s/it, Loss=1.22, MAE=1.67, MAPE=2.6
# Evaluation:  85%|▊| 17/20 [00:56<00:09,  3.12s/it, Loss=1.02, MAE=1.48, MAPE=2.8
# Evaluation:  90%|▉| 18/20 [00:56<00:06,  3.12s/it, Loss=1.02, MAE=1.48, MAPE=2.8
# Evaluation:  90%|▉| 18/20 [00:59<00:06,  3.12s/it, Loss=0.931, MAE=1.37, MAPE=2.
# Evaluation:  95%|▉| 19/20 [00:59<00:03,  3.12s/it, Loss=0.931, MAE=1.37, MAPE=2.
# Evaluation:  95%|▉| 19/20 [01:01<00:03,  3.12s/it, Loss=1.29, MAE=1.75, MAPE=2.9
# Evaluation: 100%|█| 20/20 [01:01<00:00,  2.87s/it, Loss=1.29, MAE=1.75, MAPE=2.9
# Epochs:  10%|███▎                             | 1/10 [08:21<1:15:17, 501.94s/it]
# Epoch 1, Test Loss: 1.0195763468742371, Test MAE: 1.4717755317687988, Test MAPE: 2.053283214569092
# Training:   0%|                                          | 0/95 [00:00<?, ?it/s]
# Training:   0%|         | 0/95 [00:04<?, ?it/s, Loss=0.931, MAE=1.38, MAPE=1.55]
# Training:   1%| | 1/95 [00:04<06:43,  4.29s/it, Loss=0.931, MAE=1.38, MAPE=1.55]
# Training:   1%| | 1/95 [00:08<06:43,  4.29s/it, Loss=0.905, MAE=1.39, MAPE=2.41]
# Training:   2%| | 2/95 [00:08<06:35,  4.25s/it, Loss=0.905, MAE=1.39, MAPE=2.41]
# Training:   2%|  | 2/95 [00:12<06:35,  4.25s/it, Loss=1.26, MAE=1.72, MAPE=2.69]
# Training:   3%|  | 3/95 [00:12<06:30,  4.24s/it, Loss=1.26, MAE=1.72, MAPE=2.69]
# Training:   3%|  | 3/95 [00:16<06:30,  4.24s/it, Loss=1.09, MAE=1.57, MAPE=2.26]
# Training:   4%|  | 4/95 [00:16<06:25,  4.23s/it, Loss=1.09, MAE=1.57, MAPE=2.26]
# Training:   4%|  | 4/95 [00:21<06:25,  4.23s/it, Loss=1.07, MAE=1.54, MAPE=2.31]
# Training:   5%|  | 5/95 [00:21<06:21,  4.24s/it, Loss=1.07, MAE=1.54, MAPE=2.31]
# Training:   5%|▏  | 5/95 [00:25<06:21,  4.24s/it, Loss=1.07, MAE=1.53, MAPE=2.3]
# Training:   6%|▏  | 6/95 [00:25<06:16,  4.23s/it, Loss=1.07, MAE=1.53, MAPE=2.3]
# Training:   6%|▏ | 6/95 [00:29<06:16,  4.23s/it, Loss=1.05, MAE=1.52, MAPE=3.43]
# Training:   7%|▏ | 7/95 [00:29<06:12,  4.23s/it, Loss=1.05, MAE=1.52, MAPE=3.43]
# Training:   7%|▏ | 7/95 [00:33<06:12,  4.23s/it, Loss=1.24, MAE=1.72, MAPE=2.89]
# Training:   8%|▏ | 8/95 [00:33<06:08,  4.24s/it, Loss=1.24, MAE=1.72, MAPE=2.89]
# Training:   8%|▏ | 8/95 [00:38<06:08,  4.24s/it, Loss=0.942, MAE=1.4, MAPE=2.05]
# Training:   9%|▏ | 9/95 [00:38<06:04,  4.23s/it, Loss=0.942, MAE=1.4, MAPE=2.05]
# Training:   9%|▏ | 9/95 [00:42<06:04,  4.23s/it, Loss=1.14, MAE=1.62, MAPE=2.52]
# Training:  11%| | 10/95 [00:42<06:00,  4.24s/it, Loss=1.14, MAE=1.62, MAPE=2.52]
# Training:  11%| | 10/95 [00:46<06:00,  4.24s/it, Loss=0.878, MAE=1.31, MAPE=1.72
# Training:  12%| | 11/95 [00:46<05:55,  4.23s/it, Loss=0.878, MAE=1.31, MAPE=1.72
# Training:  12%|▏ | 11/95 [00:50<05:55,  4.23s/it, Loss=1.23, MAE=1.7, MAPE=2.77]
# Training:  13%|▎ | 12/95 [00:50<05:52,  4.24s/it, Loss=1.23, MAE=1.7, MAPE=2.77]
# Training:  13%|▏| 12/95 [00:55<05:52,  4.24s/it, Loss=1.22, MAE=1.69, MAPE=3.04]
# Training:  14%|▏| 13/95 [00:55<05:49,  4.26s/it, Loss=1.22, MAE=1.69, MAPE=3.04]
# Training:  14%|▏| 13/95 [00:59<05:49,  4.26s/it, Loss=0.874, MAE=1.34, MAPE=2.55
# Training:  15%|▏| 14/95 [00:59<05:46,  4.28s/it, Loss=0.874, MAE=1.34, MAPE=2.55
# Training:  15%|▏| 14/95 [01:03<05:46,  4.28s/it, Loss=0.958, MAE=1.41, MAPE=1.67
# Training:  16%|▏| 15/95 [01:03<05:44,  4.30s/it, Loss=0.958, MAE=1.41, MAPE=1.67
# Training:  16%|▋   | 15/95 [01:08<05:44,  4.30s/it, Loss=1.55, MAE=2, MAPE=2.65]
# Training:  17%|▋   | 16/95 [01:08<05:40,  4.31s/it, Loss=1.55, MAE=2, MAPE=2.65]
# Training:  17%|▏| 16/95 [01:12<05:40,  4.31s/it, Loss=0.715, MAE=1.17, MAPE=1.83
# Training:  18%|▏| 17/95 [01:12<05:36,  4.32s/it, Loss=0.715, MAE=1.17, MAPE=1.83
# Training:  18%|▏| 17/95 [01:16<05:36,  4.32s/it, Loss=0.967, MAE=1.4, MAPE=1.27]
# Training:  19%|▏| 18/95 [01:16<05:30,  4.29s/it, Loss=0.967, MAE=1.4, MAPE=1.27]
# Training:  19%|▏| 18/95 [01:20<05:30,  4.29s/it, Loss=0.964, MAE=1.42, MAPE=2.47
# Training:  20%|▏| 19/95 [01:20<05:25,  4.28s/it, Loss=0.964, MAE=1.42, MAPE=2.47
# Training:  20%|▏| 19/95 [01:25<05:25,  4.28s/it, Loss=1.04, MAE=1.47, MAPE=1.87]
# Training:  21%|▏| 20/95 [01:25<05:19,  4.26s/it, Loss=1.04, MAE=1.47, MAPE=1.87]
# Training:  21%|▏| 20/95 [01:29<05:19,  4.26s/it, Loss=0.961, MAE=1.39, MAPE=1.48
# Training:  22%|▏| 21/95 [01:29<05:16,  4.28s/it, Loss=0.961, MAE=1.39, MAPE=1.48
# Training:  22%|▍ | 21/95 [01:33<05:16,  4.28s/it, Loss=1.04, MAE=1.49, MAPE=1.3]
# Training:  23%|▍ | 22/95 [01:33<05:10,  4.25s/it, Loss=1.04, MAE=1.49, MAPE=1.3]
# Training:  23%|▏| 22/95 [01:37<05:10,  4.25s/it, Loss=1.13, MAE=1.56, MAPE=1.04]
# Training:  24%|▏| 23/95 [01:37<05:04,  4.23s/it, Loss=1.13, MAE=1.56, MAPE=1.04]
# Training:  24%|▏| 23/95 [01:42<05:04,  4.23s/it, Loss=1.23, MAE=1.69, MAPE=1.42]
# Training:  25%|▎| 24/95 [01:42<05:00,  4.23s/it, Loss=1.23, MAE=1.69, MAPE=1.42]
# Training:  25%|▎| 24/95 [01:46<05:00,  4.23s/it, Loss=1.04, MAE=1.48, MAPE=1.64]
# Training:  26%|▎| 25/95 [01:46<04:54,  4.21s/it, Loss=1.04, MAE=1.48, MAPE=1.64]
# Training:  26%|▎| 25/95 [01:50<04:54,  4.21s/it, Loss=1.19, MAE=1.66, MAPE=1.35]
# Training:  27%|▎| 26/95 [01:50<04:49,  4.20s/it, Loss=1.19, MAE=1.66, MAPE=1.35]
# Training:  27%|▎| 26/95 [01:54<04:49,  4.20s/it, Loss=1.27, MAE=1.73, MAPE=1.74]
# Training:  28%|▎| 27/95 [01:54<04:44,  4.19s/it, Loss=1.27, MAE=1.73, MAPE=1.74]
# Training:  28%|▎| 27/95 [01:58<04:44,  4.19s/it, Loss=1.17, MAE=1.61, MAPE=1.57]
# Training:  29%|▎| 28/95 [01:58<04:40,  4.18s/it, Loss=1.17, MAE=1.61, MAPE=1.57]
# Training:  29%|▎| 28/95 [02:02<04:40,  4.18s/it, Loss=0.828, MAE=1.28, MAPE=2.92
# Training:  31%|▎| 29/95 [02:02<04:35,  4.18s/it, Loss=0.828, MAE=1.28, MAPE=2.92
# Training:  31%|▌ | 29/95 [02:07<04:35,  4.18s/it, Loss=1.04, MAE=1.48, MAPE=2.2]
# Training:  32%|▋ | 30/95 [02:07<04:31,  4.17s/it, Loss=1.04, MAE=1.48, MAPE=2.2]
# Training:  32%|▎| 30/95 [02:11<04:31,  4.17s/it, Loss=0.978, MAE=1.43, MAPE=2.43
# Training:  33%|▎| 31/95 [02:11<04:25,  4.15s/it, Loss=0.978, MAE=1.43, MAPE=2.43
# Training:  33%|▎| 31/95 [02:15<04:25,  4.15s/it, Loss=1.28, MAE=1.75, MAPE=2.87]
# Training:  34%|▎| 32/95 [02:15<04:23,  4.19s/it, Loss=1.28, MAE=1.75, MAPE=2.87]
# Training:  34%|▎| 32/95 [02:20<04:23,  4.19s/it, Loss=1.19, MAE=1.65, MAPE=2.47]
# Training:  35%|▎| 33/95 [02:20<04:27,  4.32s/it, Loss=1.19, MAE=1.65, MAPE=2.47]
# Training:  35%|▎| 33/95 [02:24<04:27,  4.32s/it, Loss=1.11, MAE=1.57, MAPE=2.28]
# Training:  36%|▎| 34/95 [02:24<04:24,  4.33s/it, Loss=1.11, MAE=1.57, MAPE=2.28]
# Training:  36%|▎| 34/95 [02:28<04:24,  4.33s/it, Loss=1.21, MAE=1.69, MAPE=2.12]
# Training:  37%|▎| 35/95 [02:28<04:17,  4.29s/it, Loss=1.21, MAE=1.69, MAPE=2.12]
# Training:  37%|▎| 35/95 [02:32<04:17,  4.29s/it, Loss=0.955, MAE=1.41, MAPE=3.54
# Training:  38%|▍| 36/95 [02:32<04:12,  4.29s/it, Loss=0.955, MAE=1.41, MAPE=3.54
# Training:  38%|▍| 36/95 [02:37<04:12,  4.29s/it, Loss=1.11, MAE=1.57, MAPE=1.55]
# Training:  39%|▍| 37/95 [02:37<04:06,  4.26s/it, Loss=1.11, MAE=1.57, MAPE=1.55]
# Training:  39%|▍| 37/95 [02:41<04:06,  4.26s/it, Loss=0.755, MAE=1.19, MAPE=2.63
# Training:  40%|▍| 38/95 [02:41<04:01,  4.24s/it, Loss=0.755, MAE=1.19, MAPE=2.63
# Training:  40%|▊ | 38/95 [02:45<04:01,  4.24s/it, Loss=1.09, MAE=1.53, MAPE=0.8]
# Training:  41%|▊ | 39/95 [02:45<03:56,  4.22s/it, Loss=1.09, MAE=1.53, MAPE=0.8]
# Training:  41%|▊ | 39/95 [02:49<03:56,  4.22s/it, Loss=1.11, MAE=1.55, MAPE=1.6]
# Training:  42%|▊ | 40/95 [02:49<03:51,  4.20s/it, Loss=1.11, MAE=1.55, MAPE=1.6]
# Training:  42%|▊ | 40/95 [02:53<03:51,  4.20s/it, Loss=1.07, MAE=1.52, MAPE=2.1]
# Training:  43%|▊ | 41/95 [02:53<03:46,  4.19s/it, Loss=1.07, MAE=1.52, MAPE=2.1]
# Training:  43%|▍| 41/95 [02:57<03:46,  4.19s/it, Loss=1.01, MAE=1.45, MAPE=1.64]
# Training:  44%|▍| 42/95 [02:57<03:41,  4.18s/it, Loss=1.01, MAE=1.45, MAPE=1.64]
# Training:  44%|▍| 42/95 [03:02<03:41,  4.18s/it, Loss=1.07, MAE=1.52, MAPE=2.54]
# Training:  45%|▍| 43/95 [03:02<03:36,  4.16s/it, Loss=1.07, MAE=1.52, MAPE=2.54]
# Training:  45%|▍| 43/95 [03:06<03:36,  4.16s/it, Loss=1.12, MAE=1.55, MAPE=1.73]
# Training:  46%|▍| 44/95 [03:06<03:31,  4.14s/it, Loss=1.12, MAE=1.55, MAPE=1.73]
# Training:  46%|▍| 44/95 [03:10<03:31,  4.14s/it, Loss=1.06, MAE=1.51, MAPE=1.28]
# Training:  47%|▍| 45/95 [03:10<03:27,  4.15s/it, Loss=1.06, MAE=1.51, MAPE=1.28]
# Training:  47%|▍| 45/95 [03:14<03:27,  4.15s/it, Loss=1.12, MAE=1.55, MAPE=1.42]
# Training:  48%|▍| 46/95 [03:14<03:23,  4.15s/it, Loss=1.12, MAE=1.55, MAPE=1.42]
# Training:  48%|▉ | 46/95 [03:18<03:23,  4.15s/it, Loss=1.14, MAE=1.6, MAPE=1.65]
# Training:  49%|▉ | 47/95 [03:18<03:19,  4.16s/it, Loss=1.14, MAE=1.6, MAPE=1.65]
# Training:  49%|▍| 47/95 [03:22<03:19,  4.16s/it, Loss=0.84, MAE=1.28, MAPE=0.902
# Training:  51%|▌| 48/95 [03:22<03:15,  4.16s/it, Loss=0.84, MAE=1.28, MAPE=0.902
# Training:  51%|▌| 48/95 [03:27<03:15,  4.16s/it, Loss=1.13, MAE=1.56, MAPE=2.94]
# Training:  52%|▌| 49/95 [03:27<03:11,  4.16s/it, Loss=1.13, MAE=1.56, MAPE=2.94]
# Training:  52%|▌| 49/95 [03:31<03:11,  4.16s/it, Loss=1.15, MAE=1.62, MAPE=1.73]
# Training:  53%|▌| 50/95 [03:31<03:07,  4.16s/it, Loss=1.15, MAE=1.62, MAPE=1.73]
# Training:  53%|▌| 50/95 [03:35<03:07,  4.16s/it, Loss=1.17, MAE=1.63, MAPE=1.91]
# Training:  54%|▌| 51/95 [03:35<03:03,  4.16s/it, Loss=1.17, MAE=1.63, MAPE=1.91]
# Training:  54%|▌| 51/95 [03:39<03:03,  4.16s/it, Loss=1.08, MAE=1.54, MAPE=2.39]
# Training:  55%|▌| 52/95 [03:39<02:58,  4.16s/it, Loss=1.08, MAE=1.54, MAPE=2.39]
# Training:  55%|▌| 52/95 [03:43<02:58,  4.16s/it, Loss=1.11, MAE=1.58, MAPE=1.97]
# Training:  56%|▌| 53/95 [03:43<02:54,  4.16s/it, Loss=1.11, MAE=1.58, MAPE=1.97]
# Training:  56%|▌| 53/95 [03:47<02:54,  4.16s/it, Loss=1.18, MAE=1.67, MAPE=2.62]
# Training:  57%|▌| 54/95 [03:47<02:50,  4.16s/it, Loss=1.18, MAE=1.67, MAPE=2.62]
# Training:  57%|█▏| 54/95 [03:51<02:50,  4.16s/it, Loss=1.13, MAE=1.6, MAPE=1.86]
# Training:  58%|█▏| 55/95 [03:51<02:46,  4.15s/it, Loss=1.13, MAE=1.6, MAPE=1.86]
# Training:  58%|▌| 55/95 [03:56<02:46,  4.15s/it, Loss=1.08, MAE=1.57, MAPE=2.46]
# Training:  59%|▌| 56/95 [03:56<02:40,  4.13s/it, Loss=1.08, MAE=1.57, MAPE=2.46]
# Training:  59%|▌| 56/95 [04:00<02:40,  4.13s/it, Loss=0.995, MAE=1.45, MAPE=1.35
# Training:  60%|▌| 57/95 [04:00<02:36,  4.11s/it, Loss=0.995, MAE=1.45, MAPE=1.35
# Training:  60%|█▏| 57/95 [04:04<02:36,  4.11s/it, Loss=1.02, MAE=1.48, MAPE=2.6]
# Training:  61%|█▏| 58/95 [04:04<02:31,  4.10s/it, Loss=1.02, MAE=1.48, MAPE=2.6]
# Training:  61%|▌| 58/95 [04:08<02:31,  4.10s/it, Loss=1.18, MAE=1.66, MAPE=2.33]
# Training:  62%|▌| 59/95 [04:08<02:27,  4.09s/it, Loss=1.18, MAE=1.66, MAPE=2.33]
# Training:  62%|▌| 59/95 [04:12<02:27,  4.09s/it, Loss=0.92, MAE=1.37, MAPE=1.85]
# Training:  63%|▋| 60/95 [04:12<02:23,  4.10s/it, Loss=0.92, MAE=1.37, MAPE=1.85]
# Training:  63%|▋| 60/95 [04:16<02:23,  4.10s/it, Loss=0.91, MAE=1.36, MAPE=2.28]
# Training:  64%|▋| 61/95 [04:16<02:19,  4.09s/it, Loss=0.91, MAE=1.36, MAPE=2.28]
# Training:  64%|▋| 61/95 [04:20<02:19,  4.09s/it, Loss=0.733, MAE=1.14, MAPE=1.88
# Training:  65%|▋| 62/95 [04:20<02:15,  4.09s/it, Loss=0.733, MAE=1.14, MAPE=1.88
# Training:  65%|▋| 62/95 [04:24<02:15,  4.09s/it, Loss=0.826, MAE=1.26, MAPE=1.22
# Training:  66%|▋| 63/95 [04:24<02:11,  4.11s/it, Loss=0.826, MAE=1.26, MAPE=1.22
# Training:  66%|▋| 63/95 [04:28<02:11,  4.11s/it, Loss=1.05, MAE=1.52, MAPE=1.48]
# Training:  67%|▋| 64/95 [04:28<02:07,  4.12s/it, Loss=1.05, MAE=1.52, MAPE=1.48]
# Training:  67%|▋| 64/95 [04:33<02:07,  4.12s/it, Loss=0.925, MAE=1.4, MAPE=1.76]
# Training:  68%|▋| 65/95 [04:33<02:04,  4.13s/it, Loss=0.925, MAE=1.4, MAPE=1.76]
# Training:  68%|▋| 65/95 [04:37<02:04,  4.13s/it, Loss=0.81, MAE=1.23, MAPE=1.53]
# Training:  69%|▋| 66/95 [04:37<01:59,  4.14s/it, Loss=0.81, MAE=1.23, MAPE=1.53]
# Training:  69%|▋| 66/95 [04:41<01:59,  4.14s/it, Loss=1.06, MAE=1.53, MAPE=0.97]
# Training:  71%|▋| 67/95 [04:41<01:55,  4.13s/it, Loss=1.06, MAE=1.53, MAPE=0.97]
# Training:  71%|▋| 67/95 [04:45<01:55,  4.13s/it, Loss=0.806, MAE=1.22, MAPE=2.11
# Training:  72%|▋| 68/95 [04:45<01:51,  4.11s/it, Loss=0.806, MAE=1.22, MAPE=2.11
# Training:  72%|▋| 68/95 [04:49<01:51,  4.11s/it, Loss=0.754, MAE=1.19, MAPE=2.01
# Training:  73%|▋| 69/95 [04:49<01:46,  4.11s/it, Loss=0.754, MAE=1.19, MAPE=2.01
# Training:  73%|▋| 69/95 [04:53<01:46,  4.11s/it, Loss=0.842, MAE=1.25, MAPE=1.6]
# Training:  74%|▋| 70/95 [04:53<01:42,  4.11s/it, Loss=0.842, MAE=1.25, MAPE=1.6]
# Training:  74%|▋| 70/95 [04:57<01:42,  4.11s/it, Loss=0.934, MAE=1.35, MAPE=1.14
# Training:  75%|▋| 71/95 [04:57<01:38,  4.10s/it, Loss=0.934, MAE=1.35, MAPE=1.14
# Training:  75%|▋| 71/95 [05:01<01:38,  4.10s/it, Loss=1.07, MAE=1.48, MAPE=1.46]
# Training:  76%|▊| 72/95 [05:01<01:34,  4.09s/it, Loss=1.07, MAE=1.48, MAPE=1.46]
# Training:  76%|▊| 72/95 [05:05<01:34,  4.09s/it, Loss=0.993, MAE=1.42, MAPE=1.77
# Training:  77%|▊| 73/95 [05:05<01:29,  4.08s/it, Loss=0.993, MAE=1.42, MAPE=1.77
# Training:  77%|▊| 73/95 [05:09<01:29,  4.08s/it, Loss=1.02, MAE=1.45, MAPE=1.83]
# Training:  78%|▊| 74/95 [05:09<01:25,  4.08s/it, Loss=1.02, MAE=1.45, MAPE=1.83]
# Training:  78%|▊| 74/95 [05:13<01:25,  4.08s/it, Loss=0.995, MAE=1.45, MAPE=2.2]
# Training:  79%|▊| 75/95 [05:13<01:21,  4.09s/it, Loss=0.995, MAE=1.45, MAPE=2.2]
# Training:  79%|▊| 75/95 [05:18<01:21,  4.09s/it, Loss=0.983, MAE=1.41, MAPE=2.84
# Training:  80%|▊| 76/95 [05:18<01:17,  4.09s/it, Loss=0.983, MAE=1.41, MAPE=2.84
# Training:  80%|▊| 76/95 [05:22<01:17,  4.09s/it, Loss=0.856, MAE=1.28, MAPE=1.28
# Training:  81%|▊| 77/95 [05:22<01:13,  4.09s/it, Loss=0.856, MAE=1.28, MAPE=1.28
# Training:  81%|▊| 77/95 [05:26<01:13,  4.09s/it, Loss=0.942, MAE=1.41, MAPE=2.11
# Training:  82%|▊| 78/95 [05:26<01:09,  4.07s/it, Loss=0.942, MAE=1.41, MAPE=2.11
# Training:  82%|▊| 78/95 [05:30<01:09,  4.07s/it, Loss=0.973, MAE=1.45, MAPE=1.97
# Training:  83%|▊| 79/95 [05:30<01:05,  4.07s/it, Loss=0.973, MAE=1.45, MAPE=1.97
# Training:  83%|▊| 79/95 [05:34<01:05,  4.07s/it, Loss=0.915, MAE=1.38, MAPE=2.02
# Training:  84%|▊| 80/95 [05:34<01:00,  4.06s/it, Loss=0.915, MAE=1.38, MAPE=2.02
# Training:  84%|▊| 80/95 [05:38<01:00,  4.06s/it, Loss=0.766, MAE=1.19, MAPE=2.29
# Training:  85%|▊| 81/95 [05:38<00:56,  4.06s/it, Loss=0.766, MAE=1.19, MAPE=2.29
# Training:  85%|▊| 81/95 [05:42<00:56,  4.06s/it, Loss=0.893, MAE=1.32, MAPE=1.3]
# Training:  86%|▊| 82/95 [05:42<00:52,  4.06s/it, Loss=0.893, MAE=1.32, MAPE=1.3]
# Training:  86%|█▋| 82/95 [05:46<00:52,  4.06s/it, Loss=1.13, MAE=1.59, MAPE=1.7]
# Training:  87%|█▋| 83/95 [05:46<00:48,  4.05s/it, Loss=1.13, MAE=1.59, MAPE=1.7]
# Training:  87%|▊| 83/95 [05:50<00:48,  4.05s/it, Loss=0.747, MAE=1.18, MAPE=1.51
# Training:  88%|▉| 84/95 [05:50<00:44,  4.05s/it, Loss=0.747, MAE=1.18, MAPE=1.51
# Training:  88%|▉| 84/95 [05:54<00:44,  4.05s/it, Loss=0.911, MAE=1.35, MAPE=1.29
# Training:  89%|▉| 85/95 [05:54<00:40,  4.06s/it, Loss=0.911, MAE=1.35, MAPE=1.29
# Training:  89%|▉| 85/95 [05:58<00:40,  4.06s/it, Loss=0.635, MAE=1.05, MAPE=1.75
# Training:  91%|▉| 86/95 [05:58<00:36,  4.06s/it, Loss=0.635, MAE=1.05, MAPE=1.75
# Training:  91%|▉| 86/95 [06:02<00:36,  4.06s/it, Loss=0.831, MAE=1.24, MAPE=1.6]
# Training:  92%|▉| 87/95 [06:02<00:32,  4.06s/it, Loss=0.831, MAE=1.24, MAPE=1.6]
# Training:  92%|▉| 87/95 [06:06<00:32,  4.06s/it, Loss=0.598, MAE=0.999, MAPE=1.0
# Training:  93%|▉| 88/95 [06:06<00:28,  4.06s/it, Loss=0.598, MAE=0.999, MAPE=1.0
# Training:  93%|▉| 88/95 [06:10<00:28,  4.06s/it, Loss=0.715, MAE=1.14, MAPE=1.41
# Training:  94%|▉| 89/95 [06:10<00:24,  4.05s/it, Loss=0.715, MAE=1.14, MAPE=1.41
# Training:  94%|▉| 89/95 [06:14<00:24,  4.05s/it, Loss=0.93, MAE=1.38, MAPE=2.75]
# Training:  95%|▉| 90/95 [06:14<00:20,  4.06s/it, Loss=0.93, MAE=1.38, MAPE=2.75]
# Training:  95%|▉| 90/95 [06:18<00:20,  4.06s/it, Loss=0.793, MAE=1.23, MAPE=1.67
# Training:  96%|▉| 91/95 [06:18<00:16,  4.06s/it, Loss=0.793, MAE=1.23, MAPE=1.67
# Training:  96%|▉| 91/95 [06:22<00:16,  4.06s/it, Loss=1.04, MAE=1.47, MAPE=2.76]
# Training:  97%|▉| 92/95 [06:22<00:12,  4.06s/it, Loss=1.04, MAE=1.47, MAPE=2.76]
# Training:  97%|▉| 92/95 [06:26<00:12,  4.06s/it, Loss=0.792, MAE=1.24, MAPE=1.49
# Training:  98%|▉| 93/95 [06:26<00:08,  4.06s/it, Loss=0.792, MAE=1.24, MAPE=1.49
# Training:  98%|█▉| 93/95 [06:31<00:08,  4.06s/it, Loss=0.954, MAE=1.4, MAPE=2.4]
# Training:  99%|█▉| 94/95 [06:31<00:04,  4.05s/it, Loss=0.954, MAE=1.4, MAPE=2.4]
# Training:  99%|▉| 94/95 [06:34<00:04,  4.05s/it, Loss=0.648, MAE=1.03, MAPE=1.61
# Training: 100%|█| 95/95 [06:34<00:00,  3.95s/it, Loss=0.648, MAE=1.03, MAPE=1.61
# Epoch 2, Train Loss: 1.0017743549848859, Train MAE: 1.449711799621582, Train MAPE: 1.9635306596755981
# Evaluation:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Evaluation:   0%|       | 0/17 [00:02<?, ?it/s, Loss=0.847, MAE=1.28, MAPE=1.45]
# Evaluation:   6%| | 1/17 [00:02<00:47,  2.96s/it, Loss=0.847, MAE=1.28, MAPE=1.4
# Evaluation:   6%| | 1/17 [00:05<00:47,  2.96s/it, Loss=0.666, MAE=1.07, MAPE=1.5
# Evaluation:  12%| | 2/17 [00:05<00:44,  2.96s/it, Loss=0.666, MAE=1.07, MAPE=1.5
# Evaluation:  12%| | 2/17 [00:08<00:44,  2.96s/it, Loss=0.859, MAE=1.33, MAPE=2.3
# Evaluation:  18%|▏| 3/17 [00:08<00:41,  2.97s/it, Loss=0.859, MAE=1.33, MAPE=2.3
# Evaluation:  18%|▏| 3/17 [00:11<00:41,  2.97s/it, Loss=0.643, MAE=1.05, MAPE=1.5
# Evaluation:  24%|▏| 4/17 [00:11<00:38,  2.97s/it, Loss=0.643, MAE=1.05, MAPE=1.5
# Evaluation:  24%|▏| 4/17 [00:14<00:38,  2.97s/it, Loss=0.986, MAE=1.41, MAPE=2.7
# Evaluation:  29%|▎| 5/17 [00:14<00:35,  2.97s/it, Loss=0.986, MAE=1.41, MAPE=2.7
# Evaluation:  29%|▎| 5/17 [00:17<00:35,  2.97s/it, Loss=0.786, MAE=1.2, MAPE=2.36
# Evaluation:  35%|▎| 6/17 [00:17<00:32,  2.98s/it, Loss=0.786, MAE=1.2, MAPE=2.36
# Evaluation:  35%|▎| 6/17 [00:20<00:32,  2.98s/it, Loss=0.691, MAE=1.09, MAPE=1.2
# Evaluation:  41%|▍| 7/17 [00:20<00:29,  2.98s/it, Loss=0.691, MAE=1.09, MAPE=1.2
# Evaluation:  41%|▍| 7/17 [00:23<00:29,  2.98s/it, Loss=0.811, MAE=1.27, MAPE=2.4
# Evaluation:  47%|▍| 8/17 [00:23<00:26,  2.98s/it, Loss=0.811, MAE=1.27, MAPE=2.4
# Evaluation:  47%|▍| 8/17 [00:26<00:26,  2.98s/it, Loss=0.671, MAE=1.08, MAPE=1.5
# Evaluation:  53%|▌| 9/17 [00:26<00:23,  2.98s/it, Loss=0.671, MAE=1.08, MAPE=1.5
# Evaluation:  53%|▌| 9/17 [00:29<00:23,  2.98s/it, Loss=0.634, MAE=1.04, MAPE=0.7
# Evaluation:  59%|▌| 10/17 [00:29<00:20,  2.98s/it, Loss=0.634, MAE=1.04, MAPE=0.
# Evaluation:  59%|▌| 10/17 [00:32<00:20,  2.98s/it, Loss=0.776, MAE=1.22, MAPE=1.
# Evaluation:  65%|▋| 11/17 [00:32<00:17,  2.98s/it, Loss=0.776, MAE=1.22, MAPE=1.
# Evaluation:  65%|▋| 11/17 [00:35<00:17,  2.98s/it, Loss=0.675, MAE=1.07, MAPE=1.
# Evaluation:  71%|▋| 12/17 [00:35<00:14,  2.98s/it, Loss=0.675, MAE=1.07, MAPE=1.
# Evaluation:  71%|▋| 12/17 [00:38<00:14,  2.98s/it, Loss=0.89, MAE=1.32, MAPE=2.2
# Evaluation:  76%|▊| 13/17 [00:38<00:11,  2.98s/it, Loss=0.89, MAE=1.32, MAPE=2.2
# Evaluation:  76%|▊| 13/17 [00:41<00:11,  2.98s/it, Loss=0.684, MAE=1.11, MAPE=1.
# Evaluation:  82%|▊| 14/17 [00:41<00:08,  2.98s/it, Loss=0.684, MAE=1.11, MAPE=1.
# Evaluation:  82%|▊| 14/17 [00:44<00:08,  2.98s/it, Loss=0.619, MAE=1.05, MAPE=1.
# Evaluation:  88%|▉| 15/17 [00:44<00:05,  2.98s/it, Loss=0.619, MAE=1.05, MAPE=1.
# Evaluation:  88%|▉| 15/17 [00:47<00:05,  2.98s/it, Loss=0.919, MAE=1.35, MAPE=1.
# Evaluation:  94%|▉| 16/17 [00:47<00:02,  2.99s/it, Loss=0.919, MAE=1.35, MAPE=1.
# Evaluation:  94%|▉| 16/17 [00:50<00:02,  2.99s/it, Loss=0.86, MAE=1.3, MAPE=2.37
# Evaluation: 100%|█| 17/17 [00:50<00:00,  2.79s/it, Loss=0.86, MAE=1.3, MAPE=2.37
# Epoch 2, Val Loss: 0.7657754526418799, Val MAE: 1.1912546157836914, Val MAPE: 1.8312121629714966
# Evaluation:   0%|                                        | 0/20 [00:00<?, ?it/s]
# Evaluation:   0%|        | 0/20 [00:02<?, ?it/s, Loss=0.81, MAE=1.21, MAPE=3.24]
# Evaluation:   5%| | 1/20 [00:02<00:56,  2.98s/it, Loss=0.81, MAE=1.21, MAPE=3.24
# Evaluation:   5%| | 1/20 [00:05<00:56,  2.98s/it, Loss=1.04, MAE=1.49, MAPE=3.16
# Evaluation:  10%| | 2/20 [00:05<00:53,  2.99s/it, Loss=1.04, MAE=1.49, MAPE=3.16
# Evaluation:  10%| | 2/20 [00:08<00:53,  2.99s/it, Loss=0.751, MAE=1.17, MAPE=1.2
# Evaluation:  15%|▏| 3/20 [00:09<00:51,  3.00s/it, Loss=0.751, MAE=1.17, MAPE=1.2
# Evaluation:  15%|▏| 3/20 [00:11<00:51,  3.00s/it, Loss=0.929, MAE=1.35, MAPE=2.7
# Evaluation:  20%|▏| 4/20 [00:11<00:47,  3.00s/it, Loss=0.929, MAE=1.35, MAPE=2.7
# Evaluation:  20%|▏| 4/20 [00:14<00:47,  3.00s/it, Loss=0.834, MAE=1.26, MAPE=2.4
# Evaluation:  25%|▎| 5/20 [00:14<00:44,  2.99s/it, Loss=0.834, MAE=1.26, MAPE=2.4
# Evaluation:  25%|▎| 5/20 [00:17<00:44,  2.99s/it, Loss=0.724, MAE=1.13, MAPE=1.5
# Evaluation:  30%|▎| 6/20 [00:17<00:41,  3.00s/it, Loss=0.724, MAE=1.13, MAPE=1.5
# Evaluation:  30%|▎| 6/20 [00:20<00:41,  3.00s/it, Loss=1.01, MAE=1.46, MAPE=2.55
# Evaluation:  35%|▎| 7/20 [00:20<00:39,  3.00s/it, Loss=1.01, MAE=1.46, MAPE=2.55
# Evaluation:  35%|▎| 7/20 [00:23<00:39,  3.00s/it, Loss=0.784, MAE=1.18, MAPE=1.5
# Evaluation:  40%|▍| 8/20 [00:24<00:36,  3.01s/it, Loss=0.784, MAE=1.18, MAPE=1.5
# Evaluation:  40%|▍| 8/20 [00:26<00:36,  3.01s/it, Loss=0.771, MAE=1.18, MAPE=2.6
# Evaluation:  45%|▍| 9/20 [00:27<00:33,  3.00s/it, Loss=0.771, MAE=1.18, MAPE=2.6
# Evaluation:  45%|▍| 9/20 [00:30<00:33,  3.00s/it, Loss=1.1, MAE=1.55, MAPE=1.79]
# Evaluation:  50%|▌| 10/20 [00:30<00:30,  3.01s/it, Loss=1.1, MAE=1.55, MAPE=1.79
# Evaluation:  50%|▌| 10/20 [00:33<00:30,  3.01s/it, Loss=0.987, MAE=1.42, MAPE=2.
# Evaluation:  55%|▌| 11/20 [00:33<00:27,  3.01s/it, Loss=0.987, MAE=1.42, MAPE=2.
# Evaluation:  55%|▌| 11/20 [00:36<00:27,  3.01s/it, Loss=0.803, MAE=1.23, MAPE=2.
# Evaluation:  60%|▌| 12/20 [00:36<00:24,  3.01s/it, Loss=0.803, MAE=1.23, MAPE=2.
# Evaluation:  60%|▌| 12/20 [00:39<00:24,  3.01s/it, Loss=0.672, MAE=1.09, MAPE=1.
# Evaluation:  65%|▋| 13/20 [00:39<00:21,  3.02s/it, Loss=0.672, MAE=1.09, MAPE=1.
# Evaluation:  65%|▋| 13/20 [00:42<00:21,  3.02s/it, Loss=0.613, MAE=1.02, MAPE=1.
# Evaluation:  70%|▋| 14/20 [00:42<00:18,  3.02s/it, Loss=0.613, MAE=1.02, MAPE=1.
# Evaluation:  70%|▋| 14/20 [00:45<00:18,  3.02s/it, Loss=0.822, MAE=1.26, MAPE=2.
# Evaluation:  75%|▊| 15/20 [00:45<00:15,  3.02s/it, Loss=0.822, MAE=1.26, MAPE=2.
# Evaluation:  75%|▊| 15/20 [00:48<00:15,  3.02s/it, Loss=0.852, MAE=1.3, MAPE=2.6
# Evaluation:  80%|▊| 16/20 [00:48<00:12,  3.02s/it, Loss=0.852, MAE=1.3, MAPE=2.6
# Evaluation:  80%|▊| 16/20 [00:51<00:12,  3.02s/it, Loss=0.835, MAE=1.23, MAPE=1.
# Evaluation:  85%|▊| 17/20 [00:51<00:09,  3.04s/it, Loss=0.835, MAE=1.23, MAPE=1.
# Evaluation:  85%|▊| 17/20 [00:54<00:09,  3.04s/it, Loss=0.699, MAE=1.09, MAPE=2.
# Evaluation:  90%|▉| 18/20 [00:54<00:06,  3.04s/it, Loss=0.699, MAE=1.09, MAPE=2.
# Evaluation:  90%|▉| 18/20 [00:57<00:06,  3.04s/it, Loss=0.652, MAE=1.07, MAPE=1.
# Evaluation:  95%|▉| 19/20 [00:57<00:03,  3.04s/it, Loss=0.652, MAE=1.07, MAPE=1.
# Evaluation:  95%|▉| 19/20 [00:59<00:03,  3.04s/it, Loss=0.598, MAE=1.01, MAPE=1.
# Evaluation: 100%|█| 20/20 [00:59<00:00,  2.79s/it, Loss=0.598, MAE=1.01, MAPE=1.
# Epochs:  20%|██████▌                          | 2/10 [16:46<1:07:06, 503.34s/it]
# Epoch 2, Test Loss: 0.8137224614620209, Test MAE: 1.23651123046875, Test MAPE: 2.1053876876831055
# Training:   0%|                                          | 0/95 [00:00<?, ?it/s]
# Training:   0%|          | 0/95 [00:04<?, ?it/s, Loss=1.07, MAE=1.51, MAPE=2.77]
# Training:   1%|  | 1/95 [00:04<06:45,  4.31s/it, Loss=1.07, MAE=1.51, MAPE=2.77]
# Training:   1%| | 1/95 [00:08<06:45,  4.31s/it, Loss=0.644, MAE=1.06, MAPE=1.61]
# Training:   2%| | 2/95 [00:08<06:28,  4.18s/it, Loss=0.644, MAE=1.06, MAPE=1.61]
# Training:   2%| | 2/95 [00:12<06:28,  4.18s/it, Loss=0.728, MAE=1.14, MAPE=1.74]
# Training:   3%| | 3/95 [00:12<06:21,  4.15s/it, Loss=0.728, MAE=1.14, MAPE=1.74]
# Training:   3%|  | 3/95 [00:16<06:21,  4.15s/it, Loss=0.78, MAE=1.17, MAPE=1.86]
# Training:   4%|  | 4/95 [00:16<06:14,  4.12s/it, Loss=0.78, MAE=1.17, MAPE=1.86]
# Training:   4%|  | 4/95 [00:20<06:14,  4.12s/it, Loss=0.943, MAE=1.39, MAPE=1.5]
# Training:   5%|  | 5/95 [00:20<06:10,  4.11s/it, Loss=0.943, MAE=1.39, MAPE=1.5]
# Training:   5%| | 5/95 [00:24<06:10,  4.11s/it, Loss=0.824, MAE=1.24, MAPE=1.94]
# Training:   6%| | 6/95 [00:24<06:05,  4.10s/it, Loss=0.824, MAE=1.24, MAPE=1.94]
# Training:   6%| | 6/95 [00:28<06:05,  4.10s/it, Loss=0.649, MAE=1.01, MAPE=1.46]
# Training:   7%| | 7/95 [00:28<06:00,  4.10s/it, Loss=0.649, MAE=1.01, MAPE=1.46]
# Training:   7%|▏ | 7/95 [00:32<06:00,  4.10s/it, Loss=0.907, MAE=1.32, MAPE=2.1]
# Training:   8%|▏ | 8/95 [00:32<05:56,  4.10s/it, Loss=0.907, MAE=1.32, MAPE=2.1]
# Training:   8%| | 8/95 [00:37<05:56,  4.10s/it, Loss=0.667, MAE=1.04, MAPE=1.68]
# Training:   9%| | 9/95 [00:37<05:52,  4.10s/it, Loss=0.667, MAE=1.04, MAPE=1.68]
# Training:   9%| | 9/95 [00:41<05:52,  4.10s/it, Loss=0.819, MAE=1.19, MAPE=1.95]
# Training:  11%| | 10/95 [00:41<05:48,  4.10s/it, Loss=0.819, MAE=1.19, MAPE=1.95
# Training:  11%| | 10/95 [00:45<05:48,  4.10s/it, Loss=0.861, MAE=1.27, MAPE=1.74
# Training:  12%| | 11/95 [00:45<05:44,  4.10s/it, Loss=0.861, MAE=1.27, MAPE=1.74
# Training:  12%| | 11/95 [00:49<05:44,  4.10s/it, Loss=1.03, MAE=1.42, MAPE=1.57]
# Training:  13%|▏| 12/95 [00:49<05:40,  4.10s/it, Loss=1.03, MAE=1.42, MAPE=1.57]
# Training:  13%|▋    | 12/95 [00:53<05:40,  4.10s/it, Loss=1, MAE=1.4, MAPE=1.75]
# Training:  14%|▋    | 13/95 [00:53<05:35,  4.09s/it, Loss=1, MAE=1.4, MAPE=1.75]
# Training:  14%|▏| 13/95 [00:57<05:35,  4.09s/it, Loss=0.515, MAE=0.856, MAPE=0.8
# Training:  15%|▏| 14/95 [00:57<05:31,  4.09s/it, Loss=0.515, MAE=0.856, MAPE=0.8
# Training:  15%|▏| 14/95 [01:01<05:31,  4.09s/it, Loss=1.05, MAE=1.43, MAPE=3.38]
# Training:  16%|▏| 15/95 [01:01<05:27,  4.10s/it, Loss=1.05, MAE=1.43, MAPE=3.38]
# Training:  16%|▏| 15/95 [01:05<05:27,  4.10s/it, Loss=0.789, MAE=1.2, MAPE=2.07]
# Training:  17%|▏| 16/95 [01:05<05:23,  4.10s/it, Loss=0.789, MAE=1.2, MAPE=2.07]
# Training:  17%|▏| 16/95 [01:09<05:23,  4.10s/it, Loss=0.694, MAE=1.09, MAPE=1.64
# Training:  18%|▏| 17/95 [01:09<05:20,  4.11s/it, Loss=0.694, MAE=1.09, MAPE=1.64
# Training:  18%|▏| 17/95 [01:13<05:20,  4.11s/it, Loss=0.859, MAE=1.25, MAPE=2.3]
# Training:  19%|▏| 18/95 [01:13<05:16,  4.10s/it, Loss=0.859, MAE=1.25, MAPE=2.3]
# Training:  19%|▏| 18/95 [01:18<05:16,  4.10s/it, Loss=0.747, MAE=1.11, MAPE=2.03
# Training:  20%|▏| 19/95 [01:18<05:11,  4.10s/it, Loss=0.747, MAE=1.11, MAPE=2.03
# Training:  20%|▏| 19/95 [01:22<05:11,  4.10s/it, Loss=0.692, MAE=1.04, MAPE=1.79
# Training:  21%|▏| 20/95 [01:22<05:07,  4.10s/it, Loss=0.692, MAE=1.04, MAPE=1.79
# Training:  21%|▏| 20/95 [01:26<05:07,  4.10s/it, Loss=0.95, MAE=1.33, MAPE=2.15]
# Training:  22%|▏| 21/95 [01:26<05:03,  4.09s/it, Loss=0.95, MAE=1.33, MAPE=2.15]
# Training:  22%|▏| 21/95 [01:30<05:03,  4.09s/it, Loss=0.638, MAE=0.975, MAPE=1.3
# Training:  23%|▏| 22/95 [01:30<04:59,  4.11s/it, Loss=0.638, MAE=0.975, MAPE=1.3
# Training:  23%|▏| 22/95 [01:34<04:59,  4.11s/it, Loss=1.39, MAE=1.82, MAPE=1.88]
# Training:  24%|▏| 23/95 [01:34<04:56,  4.11s/it, Loss=1.39, MAE=1.82, MAPE=1.88]
# Training:  24%|▍ | 23/95 [01:38<04:56,  4.11s/it, Loss=1.3, MAE=1.73, MAPE=3.17]
# ...
# Evaluation:  24%|▏| 4/17 [00:16<00:41,  3.22s/it, Loss=0.876, MAE=5.2e+3, MAPE=3
# Evaluation:  29%|▎| 5/17 [00:16<00:38,  3.22s/it, Loss=0.876, MAE=5.2e+3, MAPE=3
# Evaluation:  29%|▎| 5/17 [00:19<00:38,  3.22s/it, Loss=0.794, MAE=1.75e+3, MAPE=
# Evaluation:  35%|▎| 6/17 [00:19<00:35,  3.22s/it, Loss=0.794, MAE=1.75e+3, MAPE=
# Evaluation:  35%|▎| 6/17 [00:22<00:35,  3.22s/it, Loss=0.724, MAE=3.85e+3, MAPE=
# Evaluation:  41%|▍| 7/17 [00:22<00:32,  3.23s/it, Loss=0.724, MAE=3.85e+3, MAPE=
# Evaluation:  41%|▍| 7/17 [00:25<00:32,  3.23s/it, Loss=0.794, MAE=3.45e+3, MAPE=
# Evaluation:  47%|▍| 8/17 [00:25<00:28,  3.22s/it, Loss=0.794, MAE=3.45e+3, MAPE=
# Evaluation:  47%|▍| 8/17 [00:29<00:28,  3.22s/it, Loss=0.937, MAE=3.35e+3, MAPE=
# Evaluation:  53%|▌| 9/17 [00:29<00:25,  3.22s/it, Loss=0.937, MAE=3.35e+3, MAPE=
# Evaluation:  53%|▌| 9/17 [00:32<00:25,  3.22s/it, Loss=0.745, MAE=2.5e+3, MAPE=2
# Evaluation:  59%|▌| 10/17 [00:32<00:22,  3.23s/it, Loss=0.745, MAE=2.5e+3, MAPE=
# Evaluation:  59%|▌| 10/17 [00:35<00:22,  3.23s/it, Loss=0.938, MAE=4.21e+3, MAPE
# Evaluation:  65%|▋| 11/17 [00:35<00:19,  3.22s/it, Loss=0.938, MAE=4.21e+3, MAPE
# Evaluation:  65%|▋| 11/17 [00:38<00:19,  3.22s/it, Loss=0.604, MAE=3.04e+3, MAPE
# Evaluation:  71%|▋| 12/17 [00:38<00:16,  3.23s/it, Loss=0.604, MAE=3.04e+3, MAPE
# Evaluation:  71%|▋| 12/17 [00:41<00:16,  3.23s/it, Loss=0.556, MAE=2.5e+3, MAPE=
# Evaluation:  76%|▊| 13/17 [00:41<00:12,  3.23s/it, Loss=0.556, MAE=2.5e+3, MAPE=
# Evaluation:  76%|▊| 13/17 [00:45<00:12,  3.23s/it, Loss=0.797, MAE=3.42e+3, MAPE
# Evaluation:  82%|▊| 14/17 [00:45<00:09,  3.23s/it, Loss=0.797, MAE=3.42e+3, MAPE
# Evaluation:  82%|▊| 14/17 [00:48<00:09,  3.23s/it, Loss=0.483, MAE=2.84e+3, MAPE
# Evaluation:  88%|▉| 15/17 [00:48<00:06,  3.23s/it, Loss=0.483, MAE=2.84e+3, MAPE
# Evaluation:  88%|▉| 15/17 [00:51<00:06,  3.23s/it, Loss=0.695, MAE=2.06e+3, MAPE
# Evaluation:  94%|▉| 16/17 [00:51<00:03,  3.23s/it, Loss=0.695, MAE=2.06e+3, MAPE
# Evaluation:  94%|▉| 16/17 [00:54<00:03,  3.23s/it, Loss=0.851, MAE=2.71e+3, MAPE
# Evaluation: 100%|█| 17/17 [00:54<00:00,  3.02s/it, Loss=0.851, MAE=2.71e+3, MAPE
# Epoch 9, Val Loss: 0.7442489546888015, Val MAE: 3191.43505859375, Val MAPE: 1101428480.0
# Evaluation:   0%|                                        | 0/20 [00:00<?, ?it/s]
# Evaluation:   0%|   | 0/20 [00:03<?, ?it/s, Loss=0.8, MAE=2.77e+3, MAPE=3.48e+9]
# Evaluation:   5%| | 1/20 [00:03<01:01,  3.22s/it, Loss=0.8, MAE=2.77e+3, MAPE=3.
# Evaluation:   5%| | 1/20 [00:06<01:01,  3.22s/it, Loss=0.69, MAE=4.34e+3, MAPE=3
# Evaluation:  10%| | 2/20 [00:06<00:58,  3.23s/it, Loss=0.69, MAE=4.34e+3, MAPE=3
# Evaluation:  10%| | 2/20 [00:09<00:58,  3.23s/it, Loss=0.909, MAE=2.84e+3, MAPE=
# Evaluation:  15%|▏| 3/20 [00:09<00:54,  3.23s/it, Loss=0.909, MAE=2.84e+3, MAPE=
# Evaluation:  15%|▏| 3/20 [00:12<00:54,  3.23s/it, Loss=0.769, MAE=2.99e+3, MAPE=
# Evaluation:  20%|▏| 4/20 [00:12<00:51,  3.23s/it, Loss=0.769, MAE=2.99e+3, MAPE=
# Evaluation:  20%|▏| 4/20 [00:16<00:51,  3.23s/it, Loss=0.72, MAE=2.33e+3, MAPE=7
# Evaluation:  25%|▎| 5/20 [00:16<00:48,  3.22s/it, Loss=0.72, MAE=2.33e+3, MAPE=7
# Evaluation:  25%|▎| 5/20 [00:19<00:48,  3.22s/it, Loss=0.922, MAE=4.22e+3, MAPE=
# Evaluation:  30%|▎| 6/20 [00:19<00:45,  3.23s/it, Loss=0.922, MAE=4.22e+3, MAPE=
# Evaluation:  30%|▎| 6/20 [00:22<00:45,  3.23s/it, Loss=0.827, MAE=2.83e+3, MAPE=
# Evaluation:  35%|▎| 7/20 [00:22<00:41,  3.23s/it, Loss=0.827, MAE=2.83e+3, MAPE=
# Evaluation:  35%|▎| 7/20 [00:25<00:41,  3.23s/it, Loss=0.983, MAE=1.38e+3, MAPE=
# Evaluation:  40%|▍| 8/20 [00:25<00:38,  3.22s/it, Loss=0.983, MAE=1.38e+3, MAPE=
# Evaluation:  40%|▍| 8/20 [00:29<00:38,  3.22s/it, Loss=0.688, MAE=2.38e+3, MAPE=
# Evaluation:  45%|▍| 9/20 [00:29<00:35,  3.23s/it, Loss=0.688, MAE=2.38e+3, MAPE=
# Evaluation:  45%|▍| 9/20 [00:32<00:35,  3.23s/it, Loss=0.878, MAE=3.19e+3, MAPE=
# Evaluation:  50%|▌| 10/20 [00:32<00:32,  3.22s/it, Loss=0.878, MAE=3.19e+3, MAPE
# Evaluation:  50%|▌| 10/20 [00:35<00:32,  3.22s/it, Loss=0.617, MAE=3.47e+3, MAPE
# Evaluation:  55%|▌| 11/20 [00:35<00:29,  3.22s/it, Loss=0.617, MAE=3.47e+3, MAPE
# Evaluation:  55%|▌| 11/20 [00:38<00:29,  3.22s/it, Loss=0.757, MAE=2444.75, MAPE
# Evaluation:  60%|▌| 12/20 [00:38<00:25,  3.23s/it, Loss=0.757, MAE=2444.75, MAPE
# Evaluation:  60%|▌| 12/20 [00:41<00:25,  3.23s/it, Loss=0.512, MAE=1.83e+3, MAPE
# Evaluation:  65%|▋| 13/20 [00:41<00:22,  3.22s/it, Loss=0.512, MAE=1.83e+3, MAPE
# Evaluation:  65%|▋| 13/20 [00:45<00:22,  3.22s/it, Loss=0.633, MAE=4.98e+3, MAPE
# Evaluation:  70%|▋| 14/20 [00:45<00:19,  3.22s/it, Loss=0.633, MAE=4.98e+3, MAPE
# Evaluation:  70%|▋| 14/20 [00:48<00:19,  3.22s/it, Loss=0.825, MAE=2943.13, MAPE
# Evaluation:  75%|▊| 15/20 [00:48<00:16,  3.22s/it, Loss=0.825, MAE=2943.13, MAPE
# Evaluation:  75%|▊| 15/20 [00:51<00:16,  3.22s/it, Loss=0.608, MAE=2.9e+3, MAPE=
# Evaluation:  80%|▊| 16/20 [00:51<00:12,  3.22s/it, Loss=0.608, MAE=2.9e+3, MAPE=
# Evaluation:  80%|▊| 16/20 [00:54<00:12,  3.22s/it, Loss=0.845, MAE=3.13e+3, MAPE
# Evaluation:  85%|▊| 17/20 [00:54<00:09,  3.22s/it, Loss=0.845, MAE=3.13e+3, MAPE
# Evaluation:  85%|▊| 17/20 [00:58<00:09,  3.22s/it, Loss=0.878, MAE=3.42e+3, MAPE
# Evaluation:  90%|▉| 18/20 [00:58<00:06,  3.22s/it, Loss=0.878, MAE=3.42e+3, MAPE
# Evaluation:  90%|▉| 18/20 [01:01<00:06,  3.22s/it, Loss=0.612, MAE=2.44e+3, MAPE
# Evaluation:  95%|▉| 19/20 [01:01<00:03,  3.22s/it, Loss=0.612, MAE=2.44e+3, MAPE
# Evaluation:  95%|▉| 19/20 [01:03<00:03,  3.22s/it, Loss=0.513, MAE=3.18e+3, MAPE
# Evaluation: 100%|█| 20/20 [01:03<00:00,  2.95s/it, Loss=0.513, MAE=3.18e+3, MAPE
# Epochs:  90%|█████████████████████████████▋   | 9/10 [1:17:15<08:40, 520.08s/it]
# Epoch 9, Test Loss: 0.7492606431245804, Test MAE: 2999.86572265625, Test MAPE: 3245786624.0
# Training:   0%|                                          | 0/95 [00:00<?, ?it/s]
# Training:   0%|    | 0/95 [00:04<?, ?it/s, Loss=0.61, MAE=1.21e+3, MAPE=6.74e+9]
# Training:   1%| | 1/95 [00:04<06:42,  4.28s/it, Loss=0.61, MAE=1.21e+3, MAPE=6.7
# Training:   1%| | 1/95 [00:08<06:42,  4.28s/it, Loss=0.918, MAE=2.79e+3, MAPE=1.
# Training:   2%| | 2/95 [00:08<06:35,  4.26s/it, Loss=0.918, MAE=2.79e+3, MAPE=1.
# Training:   2%| | 2/95 [00:12<06:35,  4.26s/it, Loss=0.635, MAE=3151.07, MAPE=4.
# Training:   3%| | 3/95 [00:12<06:32,  4.26s/it, Loss=0.635, MAE=3151.07, MAPE=4.
# Training:   3%| | 3/95 [00:17<06:32,  4.26s/it, Loss=1.02, MAE=3.17e+3, MAPE=2.9
# Training:   4%| | 4/95 [00:17<06:27,  4.26s/it, Loss=1.02, MAE=3.17e+3, MAPE=2.9
# Training:   4%| | 4/95 [00:21<06:27,  4.26s/it, Loss=1.02, MAE=4.56e+3, MAPE=7.2
# Training:   5%| | 5/95 [00:21<06:22,  4.25s/it, Loss=1.02, MAE=4.56e+3, MAPE=7.2
# Training:   5%| | 5/95 [00:25<06:22,  4.25s/it, Loss=0.991, MAE=4427.03, MAPE=3.
# Training:   6%| | 6/95 [00:25<06:19,  4.26s/it, Loss=0.991, MAE=4427.03, MAPE=3.
# Training:   6%| | 6/95 [00:29<06:19,  4.26s/it, Loss=0.911, MAE=2.74e+3, MAPE=7.
# Training:   7%| | 7/95 [00:29<06:14,  4.26s/it, Loss=0.911, MAE=2.74e+3, MAPE=7.
# Training:   7%| | 7/95 [00:34<06:14,  4.26s/it, Loss=0.758, MAE=5.6e+3, MAPE=1.4
# Training:   8%| | 8/95 [00:34<06:10,  4.25s/it, Loss=0.758, MAE=5.6e+3, MAPE=1.4
# Training:   8%| | 8/95 [00:38<06:10,  4.25s/it, Loss=0.985, MAE=2.24e+3, MAPE=8.
# Training:   9%| | 9/95 [00:38<06:05,  4.25s/it, Loss=0.985, MAE=2.24e+3, MAPE=8.
# Training:   9%| | 9/95 [00:42<06:05,  4.25s/it, Loss=0.892, MAE=3.35e+3, MAPE=7.
# Training:  11%| | 10/95 [00:42<06:01,  4.25s/it, Loss=0.892, MAE=3.35e+3, MAPE=7
# Training:  11%| | 10/95 [00:46<06:01,  4.25s/it, Loss=0.852, MAE=2.86e+3, MAPE=3
# Training:  12%| | 11/95 [00:46<05:57,  4.25s/it, Loss=0.852, MAE=2.86e+3, MAPE=3
# Training:  12%| | 11/95 [00:51<05:57,  4.25s/it, Loss=0.699, MAE=4.04e+3, MAPE=4
# Training:  13%|▏| 12/95 [00:51<05:52,  4.25s/it, Loss=0.699, MAE=4.04e+3, MAPE=4
# Training:  13%|▏| 12/95 [00:55<05:52,  4.25s/it, Loss=0.625, MAE=2.11e+3, MAPE=3
# Training:  14%|▏| 13/95 [00:55<05:48,  4.25s/it, Loss=0.625, MAE=2.11e+3, MAPE=3
# Training:  14%|▏| 13/95 [00:59<05:48,  4.25s/it, Loss=0.794, MAE=4.76e+3, MAPE=1
# Training:  15%|▏| 14/95 [00:59<05:44,  4.26s/it, Loss=0.794, MAE=4.76e+3, MAPE=1
# Training:  15%|▏| 14/95 [01:03<05:44,  4.26s/it, Loss=0.759, MAE=2.63e+3, MAPE=6
# Training:  16%|▏| 15/95 [01:03<05:41,  4.27s/it, Loss=0.759, MAE=2.63e+3, MAPE=6
# Training:  16%|▏| 15/95 [01:08<05:41,  4.27s/it, Loss=0.784, MAE=1.67e+3, MAPE=1
# Training:  17%|▏| 16/95 [01:08<05:36,  4.26s/it, Loss=0.784, MAE=1.67e+3, MAPE=1
# Training:  17%|▏| 16/95 [01:12<05:36,  4.26s/it, Loss=0.491, MAE=2.27e+3, MAPE=9
# Training:  18%|▏| 17/95 [01:12<05:32,  4.26s/it, Loss=0.491, MAE=2.27e+3, MAPE=9
# Training:  18%|▏| 17/95 [01:16<05:32,  4.26s/it, Loss=0.879, MAE=2.07e+3, MAPE=1
# Training:  19%|▏| 18/95 [01:16<05:27,  4.26s/it, Loss=0.879, MAE=2.07e+3, MAPE=1
# Training:  19%|▏| 18/95 [01:20<05:27,  4.26s/it, Loss=0.514, MAE=2.62e+3, MAPE=3
# Training:  20%|▏| 19/95 [01:20<05:23,  4.25s/it, Loss=0.514, MAE=2.62e+3, MAPE=3
# Training:  20%|▏| 19/95 [01:25<05:23,  4.25s/it, Loss=0.835, MAE=3.88e+3, MAPE=3
# Training:  21%|▏| 20/95 [01:25<05:19,  4.26s/it, Loss=0.835, MAE=3.88e+3, MAPE=3
# Training:  21%|▏| 20/95 [01:29<05:19,  4.26s/it, Loss=0.712, MAE=2.12e+3, MAPE=6
# Training:  22%|▏| 21/95 [01:29<05:15,  4.26s/it, Loss=0.712, MAE=2.12e+3, MAPE=6
# Training:  22%|▏| 21/95 [01:33<05:15,  4.26s/it, Loss=0.919, MAE=3.11e+3, MAPE=5
# Training:  23%|▏| 22/95 [01:33<05:11,  4.26s/it, Loss=0.919, MAE=3.11e+3, MAPE=5
# Training:  23%|▏| 22/95 [01:37<05:11,  4.26s/it, Loss=0.705, MAE=2.65e+3, MAPE=7
# Training:  24%|▏| 23/95 [01:37<05:06,  4.26s/it, Loss=0.705, MAE=2.65e+3, MAPE=7
# Training:  24%|▏| 23/95 [01:42<05:06,  4.26s/it, Loss=1.21, MAE=3.4e+3, MAPE=8.6
# Training:  25%|▎| 24/95 [01:42<05:02,  4.26s/it, Loss=1.21, MAE=3.4e+3, MAPE=8.6
# Training:  25%|▎| 24/95 [01:46<05:02,  4.26s/it, Loss=0.856, MAE=2.37e+3, MAPE=2
# Training:  26%|▎| 25/95 [01:46<04:58,  4.27s/it, Loss=0.856, MAE=2.37e+3, MAPE=2
# Training:  26%|▎| 25/95 [01:50<04:58,  4.27s/it, Loss=0.759, MAE=3.48e+3, MAPE=1
# Training:  27%|▎| 26/95 [01:50<04:54,  4.27s/it, Loss=0.759, MAE=3.48e+3, MAPE=1
# Training:  27%|▎| 26/95 [01:55<04:54,  4.27s/it, Loss=0.626, MAE=2.81e+3, MAPE=6
# Training:  28%|▎| 27/95 [01:55<04:50,  4.27s/it, Loss=0.626, MAE=2.81e+3, MAPE=6
# Training:  28%|▎| 27/95 [01:59<04:50,  4.27s/it, Loss=0.965, MAE=4.1e+3, MAPE=3.
# Training:  29%|▎| 28/95 [01:59<04:45,  4.27s/it, Loss=0.965, MAE=4.1e+3, MAPE=3.
# Training:  29%|▎| 28/95 [02:03<04:45,  4.27s/it, Loss=0.742, MAE=3.41e+3, MAPE=6
# Training:  31%|▎| 29/95 [02:03<04:41,  4.26s/it, Loss=0.742, MAE=3.41e+3, MAPE=6
# Training:  31%|▎| 29/95 [02:07<04:41,  4.26s/it, Loss=1.16, MAE=2.54e+3, MAPE=1.
# Training:  32%|▎| 30/95 [02:07<04:36,  4.26s/it, Loss=1.16, MAE=2.54e+3, MAPE=1.
# Training:  32%|▎| 30/95 [02:12<04:36,  4.26s/it, Loss=0.503, MAE=2.93e+3, MAPE=1
# Training:  33%|▎| 31/95 [02:12<04:32,  4.26s/it, Loss=0.503, MAE=2.93e+3, MAPE=1
# Training:  33%|▎| 31/95 [02:16<04:32,  4.26s/it, Loss=0.858, MAE=2.55e+3, MAPE=6
# Training:  34%|▎| 32/95 [02:16<04:28,  4.26s/it, Loss=0.858, MAE=2.55e+3, MAPE=6
# Training:  34%|▎| 32/95 [02:20<04:28,  4.26s/it, Loss=0.613, MAE=1841.75, MAPE=5
# Training:  35%|▎| 33/95 [02:20<04:24,  4.26s/it, Loss=0.613, MAE=1841.75, MAPE=5
# Training:  35%|▎| 33/95 [02:24<04:24,  4.26s/it, Loss=0.801, MAE=4.26e+3, MAPE=1
# Training:  36%|▎| 34/95 [02:24<04:20,  4.27s/it, Loss=0.801, MAE=4.26e+3, MAPE=1
# Training:  36%|▎| 34/95 [02:29<04:20,  4.27s/it, Loss=1.17, MAE=4.87e+3, MAPE=7.
# Training:  37%|▎| 35/95 [02:29<04:15,  4.26s/it, Loss=1.17, MAE=4.87e+3, MAPE=7.
# Training:  37%|▎| 35/95 [02:33<04:15,  4.26s/it, Loss=0.871, MAE=3.86e+3, MAPE=1
# Training:  38%|▍| 36/95 [02:33<04:11,  4.26s/it, Loss=0.871, MAE=3.86e+3, MAPE=1
# Training:  38%|▍| 36/95 [02:37<04:11,  4.26s/it, Loss=0.662, MAE=3390.66, MAPE=1
# Training:  39%|▍| 37/95 [02:37<04:07,  4.26s/it, Loss=0.662, MAE=3390.66, MAPE=1
# Training:  39%|▍| 37/95 [02:41<04:07,  4.26s/it, Loss=0.916, MAE=2.52e+3, MAPE=6
# Training:  40%|▍| 38/95 [02:41<04:02,  4.26s/it, Loss=0.916, MAE=2.52e+3, MAPE=6
# Training:  40%|▍| 38/95 [02:46<04:02,  4.26s/it, Loss=0.647, MAE=2.45e+3, MAPE=7
# Training:  41%|▍| 39/95 [02:46<03:58,  4.26s/it, Loss=0.647, MAE=2.45e+3, MAPE=7
# Training:  41%|▍| 39/95 [02:50<03:58,  4.26s/it, Loss=0.794, MAE=2.27e+3, MAPE=3
# Training:  42%|▍| 40/95 [02:50<03:54,  4.26s/it, Loss=0.794, MAE=2.27e+3, MAPE=3
# Training:  42%|▍| 40/95 [02:54<03:54,  4.26s/it, Loss=0.772, MAE=2.72e+3, MAPE=1
# Training:  43%|▍| 41/95 [02:54<03:50,  4.26s/it, Loss=0.772, MAE=2.72e+3, MAPE=1
# Training:  43%|▍| 41/95 [02:58<03:50,  4.26s/it, Loss=0.75, MAE=4.67e+3, MAPE=2.
# Training:  44%|▍| 42/95 [02:58<03:45,  4.26s/it, Loss=0.75, MAE=4.67e+3, MAPE=2.
# Training:  44%|▍| 42/95 [03:03<03:45,  4.26s/it, Loss=0.722, MAE=2.81e+3, MAPE=6
# Training:  45%|▍| 43/95 [03:03<03:41,  4.27s/it, Loss=0.722, MAE=2.81e+3, MAPE=6
# Training:  45%|▍| 43/95 [03:07<03:41,  4.27s/it, Loss=0.632, MAE=2.25e+3, MAPE=7
# Training:  46%|▍| 44/95 [03:07<03:37,  4.27s/it, Loss=0.632, MAE=2.25e+3, MAPE=7
# Training:  46%|▍| 44/95 [03:11<03:37,  4.27s/it, Loss=0.836, MAE=2.47e+3, MAPE=1
# Training:  47%|▍| 45/95 [03:11<03:33,  4.27s/it, Loss=0.836, MAE=2.47e+3, MAPE=1
# Training:  47%|▍| 45/95 [03:16<03:33,  4.27s/it, Loss=0.912, MAE=2.94e+3, MAPE=1
# Training:  48%|▍| 46/95 [03:16<03:29,  4.27s/it, Loss=0.912, MAE=2.94e+3, MAPE=1
# Training:  48%|▍| 46/95 [03:20<03:29,  4.27s/it, Loss=0.614, MAE=2.1e+3, MAPE=4.
# Training:  49%|▍| 47/95 [03:20<03:25,  4.27s/it, Loss=0.614, MAE=2.1e+3, MAPE=4.
# Training:  49%|▍| 47/95 [03:24<03:25,  4.27s/it, Loss=0.925, MAE=2.91e+3, MAPE=6
# Training:  51%|▌| 48/95 [03:24<03:20,  4.27s/it, Loss=0.925, MAE=2.91e+3, MAPE=6
# Training:  51%|▌| 48/95 [03:28<03:20,  4.27s/it, Loss=0.512, MAE=2.35e+3, MAPE=2
# Training:  52%|▌| 49/95 [03:28<03:16,  4.27s/it, Loss=0.512, MAE=2.35e+3, MAPE=2
# Training:  52%|▌| 49/95 [03:33<03:16,  4.27s/it, Loss=0.716, MAE=1.88e+3, MAPE=3
# Training:  53%|▌| 50/95 [03:33<03:12,  4.27s/it, Loss=0.716, MAE=1.88e+3, MAPE=3
# Training:  53%|▌| 50/95 [03:37<03:12,  4.27s/it, Loss=0.675, MAE=2.7e+3, MAPE=5.
# Training:  54%|▌| 51/95 [03:37<03:07,  4.27s/it, Loss=0.675, MAE=2.7e+3, MAPE=5.
# Training:  54%|▌| 51/95 [03:41<03:07,  4.27s/it, Loss=0.518, MAE=2.16e+3, MAPE=2
# Training:  55%|▌| 52/95 [03:41<03:03,  4.26s/it, Loss=0.518, MAE=2.16e+3, MAPE=2
# Training:  55%|▌| 52/95 [03:45<03:03,  4.26s/it, Loss=0.699, MAE=2.4e+3, MAPE=1.
# Training:  56%|▌| 53/95 [03:45<02:59,  4.26s/it, Loss=0.699, MAE=2.4e+3, MAPE=1.
# Training:  56%|▌| 53/95 [03:50<02:59,  4.26s/it, Loss=0.726, MAE=2.52e+3, MAPE=4
# Training:  57%|▌| 54/95 [03:50<02:54,  4.26s/it, Loss=0.726, MAE=2.52e+3, MAPE=4
# Training:  57%|▌| 54/95 [03:54<02:54,  4.26s/it, Loss=0.762, MAE=2.11e+3, MAPE=7
# Training:  58%|▌| 55/95 [03:54<02:50,  4.26s/it, Loss=0.762, MAE=2.11e+3, MAPE=7
# Training:  58%|▌| 55/95 [03:58<02:50,  4.26s/it, Loss=0.666, MAE=3.47e+3, MAPE=3
# Training:  59%|▌| 56/95 [03:58<02:46,  4.26s/it, Loss=0.666, MAE=3.47e+3, MAPE=3
# Training:  59%|▌| 56/95 [04:03<02:46,  4.26s/it, Loss=0.694, MAE=1.93e+3, MAPE=1
# Training:  60%|▌| 57/95 [04:03<02:49,  4.46s/it, Loss=0.694, MAE=1.93e+3, MAPE=1
# Training:  60%|▌| 57/95 [04:07<02:49,  4.46s/it, Loss=0.753, MAE=4.21e+3, MAPE=6
# Training:  61%|▌| 58/95 [04:07<02:43,  4.42s/it, Loss=0.753, MAE=4.21e+3, MAPE=6
# Training:  61%|▌| 58/95 [04:12<02:43,  4.42s/it, Loss=0.928, MAE=2.19e+3, MAPE=1
# Training:  62%|▌| 59/95 [04:12<02:37,  4.38s/it, Loss=0.928, MAE=2.19e+3, MAPE=1
# Training:  62%|▌| 59/95 [04:16<02:37,  4.38s/it, Loss=0.517, MAE=2.36e+3, MAPE=5
# Training:  63%|▋| 60/95 [04:16<02:31,  4.34s/it, Loss=0.517, MAE=2.36e+3, MAPE=5
# Training:  63%|▋| 60/95 [04:20<02:31,  4.34s/it, Loss=0.784, MAE=3.13e+3, MAPE=8
# Training:  64%|▋| 61/95 [04:20<02:26,  4.31s/it, Loss=0.784, MAE=3.13e+3, MAPE=8
# Training:  64%|▋| 61/95 [04:25<02:26,  4.31s/it, Loss=0.778, MAE=2.77e+3, MAPE=9
# Training:  65%|▋| 62/95 [04:25<02:22,  4.31s/it, Loss=0.778, MAE=2.77e+3, MAPE=9
# Training:  65%|▋| 62/95 [04:29<02:22,  4.31s/it, Loss=0.638, MAE=2.61e+3, MAPE=6
# Training:  66%|▋| 63/95 [04:29<02:17,  4.31s/it, Loss=0.638, MAE=2.61e+3, MAPE=6
